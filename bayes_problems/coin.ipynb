# %% [markdown]
# I am given 99 fair coins and 1 coin that has heads on both sides.  I draw a coin from the bag and flip it 10 times.  What is the probability the drawn coin was the unfair coin?

# %% [markdown]
# # Analytic Solution
# We want to know the probability the coin drawn from the bag was the unfair coin, given it flipped heads 10 times.  Starting from Baye's theorm
# $$ P(A | B) = \frac{P(B | A) P(A)}{P(B)} $$
# we have
#     - the probability of drawing the unfair coin from the bag: $P(A)$
#     - the probability of flipping heads 10 times: $P(B)$
# and we know
# $$P(A) = 1 / 100$$
# $$P(B | A) = 1$$
# and related to the probability of not drawing the unfair coin ($P(!A)$)
# $$P(!A) = 99 / 100$$
# $$P(B | !A) = 1/2^{10}$$
# From this we can get $P(B)$ as
# $$P(B) = P(B | A) P(A) + P(B | !A) P(!A)$$
# or
# $$P(B) = 1 \times 1/100 + 1/2^{10} \times 99/100$$
# and we have everything we need to solve the problem.

# %%
p_a = 1.0 / 100.0
p_ba = 1.0
p_na = 99.0 / 100.0
p_bna = 0.5 ** 10
p_b = p_ba * p_a + p_bna * p_na
p_ab = p_ba * p_a / p_b
print('Probability the drawn coin was unfair, given it flipped heads 10 times: {:.3}'.format(p_ab))
# Out:
# Probability the drawn coin was unfair, given it flipped heads 10 times: 0.912

# %% [markdown]
# # Calculated Solution
# We can also simulate the experiment many times and see how often flipping 10 heads resulted from the unfair coin.

# %%
import numpy as np

# %%
# setup the situation
n_coins = 100
coins = np.zeros(n_coins, dtype=np.int)  # 100 coin all fair
coins[np.random.randint(1, n_coins, 1)] = 1  # make one coin unfair
n_flips = 10

# %%
# simulate drawing a coin and flipping it 10 times
n_samples = 1000000
all_heads_coins = []
for i in range(n_samples):
    coin = coins[np.random.randint(1, 100, 1)[0]]
    heads = 1
    for j in range(n_flips):
        flip = np.random.rand()  # random number between 0, 1
        if coin == 1 or flip > 0.5:
            heads = 1
        else:
            heads = 0
            break
    if heads:
        all_heads_coins.append([i, coin])

# %%
# evaluate the results
n_all_heads = len(all_heads_coins)
print('number of times flipped heads 10 times: {}'.format(n_all_heads))
all_heads_coins = np.c_[np.array(all_heads_coins), np.empty(n_all_heads)]
for i in range(n_all_heads):
    all_heads_coins[i, 2] = all_heads_coins[:i, 1].sum() * 1.0 / (i + 1)
print('probability coin was unfair: {:.4}'.format(all_heads_coins[-1, 2]))
# Out:
# number of times flipped heads 10 times: 11085
# probability coin was unfair: 0.9116

# %% [markdown]
# The answer agrees pretty well with the analytic solution.  Lets see how this changed over the course of the simulation.

# %%
import bokeh.plotting
from bokeh.palettes import Category10_10 as palette
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83746192-0a92-4297-be47-4e6fd9bac447">Loading BokehJS ...</span>
#     </div>

# %%
p = bokeh.plotting.figure(width=400, height=400,
    y_axis_label='fraction of times 10 heads was from the unfair coin',
    x_axis_label='trials')

p.line(all_heads_coins[:, 0], all_heads_coins[:, 2], 
       color=palette[0], legend='simulated result')
p.line(all_heads_coins[[0, -1], 0], [p_ab, p_ab], 
       color=palette[1], legend='analytic result')

p.legend.location = 'bottom_right'
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="75597e1a-0943-45a7-9b23-ad4247b7719a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("
type":"LegendItem"}],"location":"bottom_right","plot":{"id":"648d32aa-05a3-47c9-85d8-6512bcd3db9a","subtype":"Figure","type":"Plot"}},"id":"1983d982-ea06-47cd-8c51-97d1e11c70a4","type":"Legend"},{"attributes":{},"id":"109ec6bc-7222-48ec-80fa-876f4d031223","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[11085]},"y":{"__ndarray__":"...","dtype":"float64","shape":[11085]}}},"id":"1eb6d5a3-46ce-48e6-85d4-a10af6c2b3da","type":"ColumnDataSource"},{"attributes":{},"id":"f659cdbc-648c-4d4f-8ebe-2c106c3cf6db","type":"BasicTickFormatter"},{"attributes":{"axis_ ...

# %% [markdown]
# We see the simulated result equilibrated rather quickly to a value close to the analytic result.  We expect that running for a longer number of iterations would further improve the agreement.
#
# Lets run for another million steps, then combine the results.

# %%
# simulate drawing a coin and flipping it 10 times
n_samples = 1000000
all_heads_coins_r2 = []
for i in range(n_samples):
    coin = coins[np.random.randint(1, 100, 1)[0]]
    heads = 1
    for j in range(n_flips):
        flip = np.random.rand()  # random number between 0, 1
        if coin == 1 or flip > 0.5:
            heads = 1
        else:
            heads = 0
            break
    if heads:
        all_heads_coins_r2.append([i, coin])

# %%
# evaluate the second run
n_all_heads_r2 = len(all_heads_coins_r2)
print('number of times flipped heads 10 times: {}'.format(n_all_heads))
all_heads_coins_r2 = np.c_[np.array(all_heads_coins_r2)[:, :2], np.empty(n_all_heads_r2)]
# Out:
# number of times flipped heads 10 times: 11085

# %%
# combine the two runs
both_heads_coins = np.r_[all_heads_coins, all_heads_coins_r2]
for j in range(n_all_heads_r2):
    i = j + n_all_heads
    both_heads_coins[i, 2] = both_heads_coins[:i, 1].sum() * 1.0 / (i + 1)
    both_heads_coins[i, 0] += all_heads_coins[-1, 0]
    
print('probability coin was unfair: {:.3}'.format(both_heads_coins[-1, 2]))
# Out:
# probability coin was unfair: 0.91

# %% [markdown]
# This matches the anaalytic result to the precision shown.

# %%
p = bokeh.plotting.figure(width=400, height=400,
    y_axis_label='fraction of times 10 heads was from the unfair coin',
    x_axis_label='trials')

p.line(both_heads_coins[:, 0], both_heads_coins[:, 2], 
       color=palette[0], legend='simulated result')
p.line(both_heads_coins[[0, -1], 0], [p_ab, p_ab], 
       color=palette[1], legend='analytic result')

p.legend.location = 'bottom_right'
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6c662875-c85a-448f-90f3-6603e7f11331"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6c662875-c85a-448f-90f3-6603e7f11331");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6c662875-c85a-448f-90f3-6603e7f11331");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6c662875-c85a-448f-90f3-6603e7f11331' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"57803944-a698-4dd4-8fda-a8087ec1093f":{"roots":{"references":[{"attributes":{"data_source":{"id":"edb3da51-7fc4-4b0d-be3b-acb6dba9fc8d","type":"ColumnDataSource"},"glyph":{"id":"800a28c4-36d9-4ae5-ad06-5fba474abc2e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"452a4b2f-5afe-48c5-ba10-5e7f4466e7c0","type":"Line"},"selection_glyph":null},"id":"d5eb73d3-556e-4d99-9866-70bd8f09ec68","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"}},"id":"ee070b41-95e5-423f-9e42-c33843d226cf","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"}},"id":"dc7125fc-8cd2-4d1f-b36f-f13f968fc78c","type":"PanTool"},{"attributes":{"label":{"value":"analytic result"},"renderers":[{"id":"630e7ee9-e1d5-4be5-b596-aa2264ddb361","type":"GlyphRenderer"}]},"id":"9ed399bf-394c-40d4-b3c6-36adc207e574","type":"LegendItem"},{"attributes":{},"id":"c192db45-2b77-480e-9d39-36128af566dd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"}},"id":"0a19fa44-2fb1-42f2-9dfa-a78582a572bd","type":"SaveTool"},{"attributes":{},"id":"d0b888fa-4cb0-40c4-909f-aa04438d4271","type":"ToolEvents"},{"attributes":{},"id":"d2f5abb5-7c68-4523-ae6f-60792e9b1c2d","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAIkAAAAAA8oM+QQ==","dtype":"float64","shape":[2]},"y":[0.9118432769367765,0.9118432769367765]}},"id":"9744b2ba-a412-4f0b-975d-90d1020745c6","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"4f3a65e8-dc89-4550-8431-1ea7fe4a9b49","type":"Title"},{"attributes":{"label":{"value":"simulated result"},"renderers":[{"id":"d5eb73d3-556e-4d99-9866-70bd8f09ec68","type":"GlyphRenderer"}]},"id":"ec668ae3-6d9d-43a3-91f8-3307bb6e913d","type":"LegendItem"},{"attributes":{"items":[{"id":"ec668ae3-6d9d-43a3-91f8-3307bb6e913d","type":"LegendItem"},{"id":"9ed399bf-394c-40d4-b3c6-36adc207e574","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"}},"id":"fafd8266-63fb-401e-afa1-ccfdfe782e8e","type":"Legend"},{"attributes":{"axis_label":"trials","formatter":{"id":"c192db45-2b77-480e-9d39-36128af566dd","type":"BasicTickFormatter"},"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"75177b21-d3fc-4362-8b0d-d2718c23216b","type":"BasicTicker"}},"id":"3810349f-f30b-4f07-b562-b9469f6920ad","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"020a34b5-0b12-4c6a-99ba-52be541d5da9","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"2e5b4d98-ab28-4d4a-b3c4-dcdc680a768c","type":"BasicTicker"}},"id":"082255d6-d8ec-4bdf-aad4-f2bef80ac2c9","type":"Grid"},{"attributes":{"callback":null},"id":"1b11ff23-54e9-4028-953d-659c357249fa","type":"DataRange1d"},{"attributes":{"overlay":{"id":"fc08b463-631e-4f0b-86dd-80281b82f1d7","type":"BoxAnnotation"},"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"}},"id":"ba0cafbd-1ede-4a16-badf-318b830c33cd","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"9744b2ba-a412-4f0b-975d-90d1020745c6","type":"ColumnDataSource"},"glyph":{"id":"020a34b5-0b12-4c6a-99ba-52be541d5da9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5f761f18-0003-40e8-a860-e699f715e06f","type":"Line"},"selection_glyph":null},"id":"630e7ee9-e1d5-4be5-b596-aa2264ddb361","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"49cbde55-9576-48fa-9192-d455e40600a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"75177b21-d3fc-4362-8b0d-d2718c23216b","type":"BasicTicker"}},"id":"20af7aa1-a7d1-4988-84bb- ...
