# %% [markdown]
# I am given 99 fair coins and 1 coin that has heads on both sides.  I draw a coin from the bag and flip it 10 times.  What is the probability the drawn coin was the unfair coin?

# %% [markdown]
# # Analytic Solution
# We want to know the probability the coin drawn from the bag was the unfair coin, given it flipped heads 10 times.  Starting from Baye's theorm
# $$ P(A | B) = \frac{P(B | A) P(A)}{P(B)} $$
# we have
#     - the probability of drawing the unfair coin from the bag: $P(A)$
#     - the probability of flipping heads 10 times: $P(B)$
# and we know
# $$P(A) = 1 / 100$$
# $$P(B | A) = 1$$
# and related to the probability of not drawing the unfair coin ($P(!A)$)
# $$P(!A) = 99 / 100$$
# $$P(B | !A) = 1/2^{10}$$
# From this we can get $P(B)$ as
# $$P(B) = P(B | A) P(A) + P(B | !A) P(!A)$$
# or
# $$P(B) = 1 \times 1/100 + 1/2^{10} \times 99/100$$
# and we have everything we need to solve the problem.

# %%
p_a = 1.0 / 100.0
p_ba = 1.0
p_na = 99.0 / 100.0
p_bna = 0.5 ** 10
p_b = p_ba * p_a + p_bna * p_na
p_ab = p_ba * p_a / p_b
print('Probability the drawn coin was unfair, given it flipped heads 10 times: {:.3}'.format(p_ab))
# Out:
# Probability the drawn coin was unfair, given it flipped heads 10 times: 0.912

# %% [markdown]
# # Calculated Solution
# We can also simulate the experiment many times and see how often flipping 10 heads resulted from the unfair coin.

# %%
import numpy as np

# %%
# setup the situation
n_coins = 100
coins = np.zeros(n_coins, dtype=np.int)  # 100 coin all fair
coins[np.random.randint(1, n_coins, 1)] = 1  # make one coin unfair
n_flips = 10

# %%
# simulate drawing a coin and flipping it 10 times
n_samples = 1000000
all_heads_coins = []
for i in range(n_samples):
    coin = coins[np.random.randint(1, 100, 1)[0]]
    heads = 1
    for j in range(n_flips):
        flip = np.random.rand()  # random number between 0, 1
        if coin == 1 or flip > 0.5:
            heads = 1
        else:
            heads = 0
            break
    if heads:
        all_heads_coins.append([i, coin])

# %%
# evaluate the results
n_all_heads = len(all_heads_coins)
print('number of times flipped heads 10 times: {}'.format(n_all_heads))
all_heads_coins = np.c_[np.array(all_heads_coins), np.empty(n_all_heads)]
for i in range(n_all_heads):
    all_heads_coins[i, 2] = all_heads_coins[:i, 1].sum() * 1.0 / (i + 1)
print('probability coin was unfair: {:.4}'.format(all_heads_coins[-1, 2]))
# Out:
# number of times flipped heads 10 times: 11126
# probability coin was unfair: 0.9099

# %% [markdown]
# The answer agrees pretty well with the analytic solution.  Lets see how this changed over the course of the simulation.

# %%
import bokeh.plotting
from bokeh.palettes import Category10_10 as palette
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fa112704-138f-4fca-9e19-99cfbbeb59e3">Loading BokehJS ...</span>
#     </div>

# %%
p = bokeh.plotting.figure(width=400, height=400,
    y_axis_label='fraction of times 10 heads was from the unfair coin',
    x_axis_label='trials')

p.line(all_heads_coins[:, 0], all_heads_coins[:, 2], 
       color=palette[0], legend='simulated result')
p.line(all_heads_coins[[0, -1], 0], [p_ab, p_ab], 
       color=palette[1], legend='analytic result')

p.legend.location = 'bottom_right'
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6bf2e93b-792f-46fd-bb7d-0e3567b9f86b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6bf2e93b-792f-46fd-bb7d-0e3567b9f86b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6bf2e93b-792f-46fd-bb7d-0e3567b9f86b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6bf2e93b-792f-46fd-bb7d-0e3567b9f86b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ebcb4bd5-93dc-49be-945a-04d08597c55d":{"roots":{"references":[{"attributes":{"data_source":{"id":"a0935b12-0f2c-4817-8b7c-05b32475e6f3","type":"ColumnDataSource"},"glyph":{"id":"5aae1d7e-2312-4542-8b91-d37931687532","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bb074a89-dcf2-4b12-bc0e-33bee4c0d1a7","type":"Line"},"selection_glyph":null},"id":"2a12521b-2294-40fa-bc4d-d03573160d72","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"},"ticker":{"id":"e17d0bf2-715b-43ac-8b3d-e2d9236beffa","type":"BasicTicker"}},"id":"8e316fd6-466f-4b5b-9082-d9e2f4b2bd15","type":"Grid"},{"attributes":{},"id":"e17d0bf2-715b-43ac-8b3d-e2d9236beffa","type":"BasicTicker"},{"attributes":{"axis_label":"fraction of times 10 heads was from the unfair coin","formatter":{"id":"51de446b-715f-414c-a0d3-e195470948f1","type":"BasicTickFormatter"},"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"},"ticker":{"id":"e17d0bf2-715b-43ac-8b3d-e2d9236beffa","type":"BasicTicker"}},"id":"e5f3be5d-09bc-488d-a90e-a336917d8204","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"efabba05-dd32-4ea6-af7c-7e1406b270c4","type":"BoxAnnotation"},{"attributes":{},"id":"fa83a7dc-a8a2-4669-8a52-1d98875916ff","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5aae1d7e-2312-4542-8b91-d37931687532","type":"Line"},{"attributes":{"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"}},"id":"a3af602e-19d7-48b1-b3ce-b04c92f8bd58","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"5f11d59c-8717-4423-937a-0ba02340bf72","type":"Title"},{"attributes":{"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"}},"id":"616a0528-3294-400f-bf9d-0f320770cfff","type":"PanTool"},{"attributes":{"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"}},"id":"5077906a-0596-4a44-8ff4-dba87e396460","type":"ResetTool"},{"attributes":{"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"}},"id":"8c42d305-ca08-4693-a238-960e49999957","type":"SaveTool"},{"attributes":{"overlay":{"id":"efabba05-dd32-4ea6-af7c-7e1406b270c4","type":"BoxAnnotation"},"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"}},"id":"ea2e0384-ab72-45e9-9a67-c7986d2cf05c","type":"BoxZoomTool"},{"attributes":{},"id":"51de446b-715f-414c-a0d3-e195470948f1","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"}},"id":"47673787-0ef2-45d0-9cf5-a143190459b7","type":"HelpTool"},{"attributes":{"callback":null},"id":"bb402526-5fae-4434-aae7-714890a443ed","type":"DataRange1d"},{"attributes":{"axis_label":"trials","formatter":{"id":"fa83a7dc-a8a2-4669-8a52-1d98875916ff","type":"BasicTickFormatter"},"plot":{"id":"12bea9ff-1502-4e9a-a540-3d7503119125","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d1acd5d-67e0-48c2-950d-c2a1cadf939c","type":"BasicTicker"}},"id":"e0c4a59f-5887-4c20-85d0-da2aaa40c06a","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"616a0528-3294-400f-bf9d-0f320770cfff","type":"PanTool"},{"id":"a3af602e-19d7-48b1-b3ce-b04c92f8bd58","type":"WheelZoomTool"},{"id":"ea2e0384-ab72-45e9-9a67-c7986d2cf05c","type":"BoxZoomTool"},{"id":"8c42d305-ca08-4693-a238-960e49999957","type":"SaveTool"},{"id":"5077906a-0596-4a44-8ff4-dba87e396460","type":"ResetTool"},{"id":"47673787-0ef2-45 ...
