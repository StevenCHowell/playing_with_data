# %%
import numpy as np
import pandas as pd

# %%
import scipy.interpolate
import scipy.stats

# %%
import bokeh.plotting
import bokeh.models  # LinearAxis 
from bokeh.palettes import Category10_10 as palette

# %%
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cb548a16-00c8-4bf1-8bc9-d19a534a9b36">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Question:
# Given two normal distributions of different mean and standard deviation, consider a measurement with a value between the two means, what is the probability for it belonging to each of the two distributions?
#
# As an example, consider two groups of runners.  The first group of runners trains regularly and is in good shape.  The second group of runners does not train but still enjoy running occaisionally.  You measure how fast everyone can run the mile then calculate the mean and standard deviation for each group.  Then you find you have the time for one person but forgot to label what group they came from.  Based on their time for running the mile, what is the probability they are in the group that trains regularly?
#
# To put some numbers to this example, lets say the group that trains regularly have a mean time of 6.5 minutes with a standard deviation of 0.75 minutes and that the occasional runners have a mean time of 10 minutes with a standard devaition of 2 minutes.  Additionally, lets say there are 20 people in the faster group and 80 people in the slower group.
#
# Mean times:<br>
# $ m_1 = 6.5\,\text{min}$<br>
# $ m_2 = 12.0\,\text{min}$<br>
#
# Standard deviations:<br>
# $ s_1 = 0.75\,\text{min}$<br>
# $ s_2 = 3.0\,\text{min}$<br>
#
# Group size:<br>
# $ n_1 = 20\,\text{people}$<br>
# $ n_2 = 80\,\text{people}$<br>

# %%
m1 = 6.5
m2 = 12.0

s1 = .75
s2 = 3.0

n1 = 20
n2 = 80
n = n1 + n2

# %%
x_min = 2.0
x_max = 25.0
x = np.linspace(x_min, x_max, 200)
y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n

y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n

y = y1 + y2

p = bokeh.plotting.figure(width=400, height=300, 
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8e29d5ca-acca-49a0-95c0-e244c7567491"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8e29d5ca-acca-49a0-95c0-e244c7567491").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8e29d5ca-acca-49a0-95c0-e244c7567491");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8e29d5ca-acca-49a0-95c0-e244c7567491' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9bd388a5-d2b6-4cb7-91f1-c04161ef7312":{"roots":{"references":[{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"9343e398-a839-4029-a81c-fbbe41782bb6","type":"GlyphRenderer"}]},"id":"faf39df9-74a0-4492-ba07-e8dc5cfdd98b","type":"LegendItem"},{"attributes":{},"id":"3683412a-18d8-49ba-9f5d-2c25519e174b","type":"ToolEvents"},{"attributes":{},"id":"55be0062-a82f-4a96-a354-5c761c6d2d23","type":"BasicTicker"},{"attributes":{},"id":"4ffb3a90-a654-413e-b825-4dd6652526bf","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3fbfcc27-e482-4c11-8d8e-987bf56672e4","subtype":"Figure","type":"Plot"}},"id":"f21a2944-0d66-4581-ae20-0cd5e84a68b6","type":"WheelZoomTool"},{"attributes":{"axis_label":"% of People","formatter":{"id":"4ffb3a90-a654-413e-b825-4dd6652526bf","type":"BasicTickFormatter"},"plot":{"id":"3fbfcc27-e482-4c11-8d8e-987bf56672e4","subtype":"Figure","type":"Plot"},"ticker":{"id":"55be0062-a82f-4a96-a354-5c761c6d2d23","type":"BasicTicker"}},"id":"a7f7ce23-d72b-40fe-8acd-647b2c16e175","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"1154ae9e-c194-40d1-8832-c94743423ffc","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"15d6242b-3c7e-4762-8949-c232d1185893","type":"PanTool"},{"id":"f21a2944-0d66-4581-ae20-0cd5e84a68b6","type":"WheelZoomTool"},{"id":"43d98961-8d78-4c47-8eed-16bb23bf1002","type":"BoxZoomTool"},{"id":"cf40b3cb-52f8-44bc-844c-b0ee1081a40a","type":"SaveTool"},{"id":"778ff2a3-b340-4510-9c1c-7bd1bf708784","type":"ResetTool"},{"id":"979bbf6d-2c67-469f-8fbd-0f28a2c4e53c","type":"HelpTool"}]},"id":"1a2d25da-1b2e-45d2-a201-0f1ee9ebc923","type":"Toolbar"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a7f64c2-084d-4df4-803c-32c2bcf6fed7","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0774776f-5b3f-4768-b33d-dbeccbbe1113","type":"Line"},{"attributes":{"callback":null},"id":"79f9bc94-7868-48be-8454-c19ff233e821","type":"DataRange1d"},{"attributes":{"overlay":{"id":"a0ad45bf-5b42-4379-81cc-bf33c327ab7f","type":"BoxAnnotation"},"plot":{"id":"3fbfcc27-e482-4c11-8d8e-987bf56672e4","subtype":"Figure","type":"Plot"}},"id":"43d98961-8d78-4c47-8eed-16bb23bf1002","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"7bafcb14-7914-403a-9c2c-049730b0673d","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba20f1ec-587e-4577-ae0c-f19c2369adea","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4334ee32-63b5-4f86-8eef-8f5aeb4cf2ff","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"07d061b1-81b9-45f2-8541-d2890bab0c8a","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"3fbfcc27-e482-4c11-8d8e-987bf56672e4","subtype":"Figure","type":"Plot"},"ticker":{"id":"55be0062-a82f-4a96-a354-5c761c6d2d23","type":"BasicTicker"}},"id":"f7fb99d2-0f7d-4d57-87cc-3d16338d7e0c","type":"Grid"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"d92d1bb2-df63-45f3-b702-9103bc29b6f2","type":"BasicTickFormatter"},"plot":{"id":"3fbfcc27-e482-4c11-8d8e-987bf56672e4","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3dc046f-d81f-491b-b74b-26729b21aa69","type":"BasicTicker"}},"id":"922e6d13-bd96-44b3-aefc-07103f1c7bd9","type":"LinearAxis"},{"attributes":{},"id":"d92d1bb2-df63-45f3-b702-9103bc29b6f2","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3fbfcc27-e482-4c11-8d8e-987bf56672e4","subtype":"Figure","type" ...

# %% [markdown]
# If we calculate the area under the curves, we should get the percent of people in each group.

# %%
dx = x[1] - x[0]

# %%
a = dx * y.sum()
print(a)
# Out:
# 0.999674635352

# %%
a1 = dx * y1.sum()
print(a1)
# Out:
# 0.199999999882

# %%
a2 = dx * y2.sum()
print(a2)
# Out:
# 0.79967463547

# %% [markdown]
# Now lets consider the runner who was not labelled.
#
# My initial approach was to compare his time, $t$ to the means and standard distributions, calculating the difference between the means as
# $$
# \begin{align}
#   d_1 &= | t - m_1|\\
#   d_2 &= | t - m_2|
# \end{align}
# $$
# then calculate the probability of being in the fast group as
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                     &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_1 d_1}{s_1 d_1 + s_2 d_2} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                     &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$
#
# This probability will have the following distribution.

# %%
p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, 1-p1_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bc378108-a910-4759-8920-eaaeb11a5d4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bc378108-a910-4759-8920-eaaeb11a5d4c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc378108-a910-4759-8920-eaaeb11a5d4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc378108-a910-4759-8920-eaaeb11a5d4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f8f9e8d0-d378-478e-90d3-2060801a22ae":{"roots":{"references":[{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"88041639-f8a0-4886-8c42-d4f8658d239a","type":"Line"},{"attributes":{},"id":"29f463f7-ca6e-47cf-9351-a8c9e76c9722","type":"BasicTickFormatter"},{"attributes":{},"id":"2eacda41-4ec9-419f-910b-16a88a016bbd","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6b7bbe27-eff1-42e9-b314-b1274dd225ff","type":"Line"},{"attributes":{"label":{"value":"p fast"},"renderers":[{"id":"8a363fb3-b61b-45ac-bc9d-faab5ca17908","type":"GlyphRenderer"}]},"id":"c007c938-7c95-4830-b7eb-f3b3b3d19299","type":"LegendItem"},{"attributes":{"below":[{"id":"2cb26a76-c839-4fcf-ac66-a6ff9379aef7","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"7d45ca46-7c8c-4b38-ae5e-5331cacd7063","type":"Range1d"}},"left":[{"id":"85ee10b7-9ac5-4785-bd95-90d49d800645","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"2cb26a76-c839-4fcf-ac66-a6ff9379aef7","type":"LinearAxis"},{"id":"99baad68-254b-46c6-b9a0-70d60fa8678f","type":"Grid"},{"id":"85ee10b7-9ac5-4785-bd95-90d49d800645","type":"LinearAxis"},{"id":"28b32c02-4b57-42fd-bb39-d25f9c619d49","type":"Grid"},{"id":"260e6f85-34dd-4513-aa91-43067b733e04","type":"BoxAnnotation"},{"id":"4dc0a31d-c8e4-4826-abc0-dc4d6556be3f","type":"LinearAxis"},{"id":"064411ec-bed9-45eb-9014-5d8e2949f7f8","type":"Legend"},{"id":"42d16932-15af-4caf-bfed-a62bfae28e68","type":"GlyphRenderer"},{"id":"bd6d00c9-16fd-4d17-9490-7602bf290592","type":"GlyphRenderer"},{"id":"31e68d96-08a1-4c4b-bcae-f3409f2c9eca","type":"GlyphRenderer"},{"id":"8a363fb3-b61b-45ac-bc9d-faab5ca17908","type":"GlyphRenderer"},{"id":"492e9b00-d57c-40ee-8ead-08a48b2eef98","type":"GlyphRenderer"}],"right":[{"id":"4dc0a31d-c8e4-4826-abc0-dc4d6556be3f","type":"LinearAxis"}],"title":{"id":"97b9dac4-5c3e-4ff9-9f2c-c4cd67a2e162","type":"Title"},"tool_events":{"id":"ae86de09-87ae-4ac2-b5bf-bf8fc756a51f","type":"ToolEvents"},"toolbar":{"id":"cc5aff5b-b218-41b6-bca5-05ae996664e4","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"e8d2056f-e78f-40ce-a07a-71305f195929","type":"DataRange1d"},"y_range":{"id":"53a95a93-6bd8-4a3c-a416-8618c3d96222","type":"Range1d"}},"id":"e3f92860-bd11-4a00-bbb1-4d7f5e6dec42","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"e3f92860-bd11-4a00-bbb1-4d7f5e6dec42","subtype":"Figure","type":"Plot"}},"id":"893c905f-e4f8-42d4-a8d8-91a70b6640b0","type":"ResetTool"},{"attributes":{},"id":"cb53d8b6-38aa-4796-aa66-46ae1d8d9a15","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c8369e04-2dec-4f75-98e3-5662680688d5","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"467d31a2-ea75-4cee-aa9c-5826c5a33418","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"97b9dac4-5c3e-4ff9-9f2c-c4cd67a2e162","type":"Title"},{"attributes":{},"id":"cf4dfd8b-f8d2-4d1a-91f6-08bb9df30c3d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e3f92860-bd11-4a00-bbb1-4d7f5e6dec42","subtype":"Figure","type":"Plot"}},"id":"d4868492-6e6b-4330-a7dd-de62f7225152","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f663b898-37c8-44e4-9c69-423b71c054f4","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9722d6f-f19b-4b20-a3b3-234a0ed0163b","type":"Line"},{"attributes":{"plot":{"id":"e3f92860-bd11-4a00-bbb1-4d7f5e6dec42","subtype":"Figure","type":"Plot"}},"id":"5919141f-3211-470b-abbe-dac3bbe2ea8f","type":"SaveTool"},{"attributes":{"callback":null},"id":"e8d2056f-e78f-40ce-a07a-71305f ...

# %% [markdown]
# This is clearly wrong as the crossover from being more likely to be in fast group is much too close to the slow group.  Lets see what happens when we switch the standard deviations to use
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                      &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_2 d_1}{s_2 d_1 + s_1 d_2} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                      &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$
#
# With this change, the probability will have the following distribution.

# %%
p1_v1[mask] = 1 - s2 * d1[mask] / (s2 * d1[mask] + s1 * d2[mask])
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc63fec4-49ed-4b66-a4e2-a047a18a4242"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fc63fec4-49ed-4b66-a4e2-a047a18a4242").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc63fec4-49ed-4b66-a4e2-a047a18a4242");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc63fec4-49ed-4b66-a4e2-a047a18a4242' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca7782c1-cd64-4935-abdd-7b2e9cf58647":{"roots":{"references":[{"attributes":{"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"}},"id":"c11fb9d3-803b-45ac-8b2b-906149be3985","type":"SaveTool"},{"attributes":{"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"}},"id":"5e17e0bc-70ba-42a6-b780-b52b1b8e38dc","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"345b98fd-1964-4d00-80b8-89b322688659","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"35c9129f-28fe-4891-a61b-7c58bf637710","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"}},"id":"5959f947-e424-426c-beb7-4ec0ce2747e8","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"ebba5f83-d239-44de-9ad1-0bb857318da8","type":"Title"},{"attributes":{"axis_label":"% of People","formatter":{"id":"bff5d413-0a75-4a68-a7d4-1ddba9792bea","type":"BasicTickFormatter"},"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ad85e29-4e10-4b42-b3b7-628a8092aa03","type":"BasicTicker"}},"id":"ddf27bbf-cce5-466d-ac7d-9cfc05d1a40d","type":"LinearAxis"},{"attributes":{},"id":"bdefb40f-7e61-4750-809d-fceb1ec43618","type":"BasicTicker"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"743162a8-e1ad-46e0-b846-bef3f3f87b56","type":"GlyphRenderer"}]},"id":"7b51ac8a-81d6-4fc2-8b6b-21706ca44e65","type":"LegendItem"},{"attributes":{},"id":"0ad85e29-4e10-4b42-b3b7-628a8092aa03","type":"BasicTicker"},{"attributes":{"callback":null,"end":0.15},"id":"e4089afe-d18e-4468-90d8-8b5035a3be4d","type":"Range1d"},{"attributes":{"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"}},"id":"31da5730-16bd-4f60-a078-2467cf2a5bc6","type":"HelpTool"},{"attributes":{"data_source":{"id":"6f15261f-de8c-49e8-88f1-5a69722e28b8","type":"ColumnDataSource"},"glyph":{"id":"ede016b9-4805-4b4c-b083-533322e24e99","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"cd5a198c-e05b-4d90-8a14-a9fecf7eb79e","type":"Line"},"selection_glyph":null},"id":"945ef57c-99fd-4bab-9241-54dc1568b1fe","type":"GlyphRenderer"},{"attributes":{},"id":"162372d1-f550-4fdf-bf9d-26f07a6f5779","type":"BasicTicker"},{"attributes":{"axis_label":"Probability","formatter":{"id":"1bcd3685-50c6-4fb4-9ce0-413708bd1f9d","type":"BasicTickFormatter"},"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"},"ticker":{"id":"162372d1-f550-4fdf-bf9d-26f07a6f5779","type":"BasicTicker"},"y_range_name":"prob"},"id":"d33ac55d-d92a-4c98-87c8-cb456a66a2dd","type":"LinearAxis"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"a88a3881-3768-4e43-8a6d-5f6dcbf04e9a","type":"BasicTickFormatter"},"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"},"ticker":{"id":"bdefb40f-7e61-4750-809d-fceb1ec43618","type":"BasicTicker"}},"id":"4e31d5fa-7fcd-4a5c-bd9e-9c5bdde6c3d5","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"997ff64c-8ce4-46c1-8df6-0e7bc07ee90d","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be38d0e5-6cef-44ca-90c2-c6068757a464","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"911b83ac-0b5b-40fd-9bd7-efd1381fe655","type":"Line"},{"attributes":{"plot":{"id":"42554fb8-f925-48e5-9d8a-bfd09a04692c","subtype":"Figure","type":"Plot"},"ticke ...

# %% [markdown]
# This seems more reasonable but I did not take into account the relative difference in the size of the groups.  Lets add a scale factor related to this difference.

# %% [markdown]
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                      &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_2 d_1 \frac{n_1}{n}}{s_2 d_1 \frac{n_1}{n} + s_1 d_2 \frac{n_2}{n}} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                      &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$

# %%
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7f5e4721-faa2-41a3-8d05-52da937779a5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7f5e4721-faa2-41a3-8d05-52da937779a5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7f5e4721-faa2-41a3-8d05-52da937779a5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7f5e4721-faa2-41a3-8d05-52da937779a5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"15e84028-8afa-49f8-87c8-9fa23b892444":{"roots":{"references":[{"attributes":{"data_source":{"id":"e5d675c5-1c2f-42ef-8fa6-12e93e4cf5e8","type":"ColumnDataSource"},"glyph":{"id":"8599ddb4-293e-42ce-aa73-22b1289bc479","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dd2218e2-5f73-40d9-a47a-5e67b8c2b8c6","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"e660086d-21ab-4b32-82fa-ecbf4af6e6c3","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"},"ticker":{"id":"00918ec1-dbd3-442d-9bda-294d97761f78","type":"BasicTicker"}},"id":"ecbe9f55-2510-45f4-8b48-e4105d2f5085","type":"Grid"},{"attributes":{"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"}},"id":"9f920b9c-d443-4443-92c4-1634a0a658ab","type":"PanTool"},{"attributes":{"items":[{"id":"f9abed45-a056-4b86-88ca-24797eb3f6cd","type":"LegendItem"},{"id":"74918920-dfc1-4124-b1ac-4fde27930839","type":"LegendItem"},{"id":"d7a6c1e6-92b6-418f-b08b-b48bd818777c","type":"LegendItem"},{"id":"308d2e01-7037-4427-b340-fa19cee2ab9b","type":"LegendItem"},{"id":"716b57e1-c3f2-4f52-977a-90779058a29e","type":"LegendItem"}],"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"}},"id":"4c3d2245-887b-434d-873c-92ab6429d12f","type":"Legend"},{"attributes":{"callback":null,"end":0.15},"id":"8dcc1185-00b9-46e7-9137-0a537598152f","type":"Range1d"},{"attributes":{"label":{"value":"p slow"},"renderers":[{"id":"e660086d-21ab-4b32-82fa-ecbf4af6e6c3","type":"GlyphRenderer"}]},"id":"716b57e1-c3f2-4f52-977a-90779058a29e","type":"LegendItem"},{"attributes":{"axis_label":"Probability","formatter":{"id":"a95a7a5d-77c3-4cd6-afbb-21fc627334e9","type":"BasicTickFormatter"},"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"},"ticker":{"id":"506f63e3-2691-4816-af24-bc61f938ab8e","type":"BasicTicker"},"y_range_name":"prob"},"id":"84791021-87a2-4746-bf25-4c5979f2fa95","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"4e069ca3-8829-4a80-9ca4-7ac34e4bd4b7","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1928911b-f6fb-402e-8bf8-da412fb73d9e","type":"Line"},{"attributes":{},"id":"3a385da7-993b-4750-842b-5532ec8aa7db","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"}},"id":"1dcacc79-3222-4c89-89d0-b68ba39f1adc","type":"HelpTool"},{"attributes":{"label":{"value":"slow group"},"renderers":[{"id":"5acda21b-3d10-44ed-b7db-6a0c37beb285","type":"GlyphRenderer"}]},"id":"d7a6c1e6-92b6-418f-b08b-b48bd818777c","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a920f14-ff89-4131-88b4-46413e080e70","type":"Line"},{"attributes":{"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"}},"id":"cc9dd911-a15a-4bc2-a462-89d07db14119","type":"WheelZoomTool"},{"attributes":{},"id":"00918ec1-dbd3-442d-9bda-294d97761f78","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"e5d675c5-1c2f-42ef-8fa6-12e93e4cf5e8","type":"ColumnDataSource"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"95928cfd-8b28-4d7d-b8b4-4f2b29fe458d","type":"BasicTickFormatter"},"plot":{"id":"f1c5fbaf-f4f8-4b38-b2b1-de9ed9480b61","subtype":"Figure","type":"Plot"},"ticker":{"id":"88a3f850-5a17-48ab-8fb1-77580c032254","type":"BasicTicker"}},"id":"33dd0672-39b2-467f-be14-6e5f4c1a7579","type":"LinearAxis"},{"attributes":{"plot":{"id":"f1 ...

# %% [markdown]
# This looks like a linear switch between the two means.  How does this change if we change one of the mean values?  Let make $m_2=15.0$ minutes.

# %%
m2 = 15.0

y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n
y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n
y = y1 + y2

p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fd62c9d8-11fc-4628-9cc2-997bb4bd2eda"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fd62c9d8-11fc-4628-9cc2-997bb4bd2eda").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fd62c9d8-11fc-4628-9cc2-997bb4bd2eda");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fd62c9d8-11fc-4628-9cc2-997bb4bd2eda' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3c66a8f3-3f2d-4866-8591-48e0ee7eebd7":{"roots":{"references":[{"attributes":{"callback":null},"id":"b07b82ac-8594-4937-b97c-836afcc0c4f5","type":"DataRange1d"},{"attributes":{"data_source":{"id":"e4f5a93d-d701-4a44-b202-f257283a87b2","type":"ColumnDataSource"},"glyph":{"id":"cd356bc1-0200-4855-b03e-7964c04a1b70","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"cf2d9a4a-0e26-41fc-a7f8-12f09cd2be9c","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"53fd8155-33bf-4d1b-bad8-63667cfaef96","type":"GlyphRenderer"},{"attributes":{},"id":"dae81dca-bc97-498e-9e2a-63886775929e","type":"ToolEvents"},{"attributes":{"axis_label":"% of People","formatter":{"id":"0822db96-181d-4e72-a125-ab81a8ee30be","type":"BasicTickFormatter"},"plot":{"id":"8469a516-5a4b-42d8-b873-ad6d94772921","subtype":"Figure","type":"Plot"},"ticker":{"id":"bcab9b33-1c69-4e8b-a406-3c26619676d8","type":"BasicTicker"}},"id":"8f6bcd5f-6335-4bec-954a-20a01d379f5a","type":"LinearAxis"},{"attributes":{"callback":null,"end":0.15},"id":"d92e475b-5253-42fb-ac51-8b095bc48a6a","type":"Range1d"},{"attributes":{"label":{"value":"slow group"},"renderers":[{"id":"05c377e1-db3b-404e-8f08-79f8b6fb87b6","type":"GlyphRenderer"}]},"id":"24e2c191-7a82-4a0e-969c-77abe99207a8","type":"LegendItem"},{"attributes":{"below":[{"id":"ce9abafa-11ac-4994-9b95-cc10b37ccef1","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"932d4fe3-26a1-47f3-8fa7-ae21cf9ed00d","type":"Range1d"}},"left":[{"id":"8f6bcd5f-6335-4bec-954a-20a01d379f5a","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"ce9abafa-11ac-4994-9b95-cc10b37ccef1","type":"LinearAxis"},{"id":"99ce8ec1-844c-4f00-a39b-b3fe97a14ec8","type":"Grid"},{"id":"8f6bcd5f-6335-4bec-954a-20a01d379f5a","type":"LinearAxis"},{"id":"4c50e03f-277d-46f6-867f-06b354f1bbc8","type":"Grid"},{"id":"6f9815f9-d5ae-4044-b7e2-8a012c5ea3cc","type":"BoxAnnotation"},{"id":"f0287b62-19e8-48fd-843a-1c3bbefc5b0f","type":"LinearAxis"},{"id":"23bcde78-73ed-4bb2-af5a-e68479f10fb9","type":"Legend"},{"id":"0e7737b1-f45d-4b4b-bace-8f8aaf2ea014","type":"GlyphRenderer"},{"id":"305234a3-a4b3-4498-ba52-bd11ddc27fe3","type":"GlyphRenderer"},{"id":"05c377e1-db3b-404e-8f08-79f8b6fb87b6","type":"GlyphRenderer"},{"id":"53fd8155-33bf-4d1b-bad8-63667cfaef96","type":"GlyphRenderer"},{"id":"4b118cf7-330a-4685-a230-143b4d44ffd0","type":"GlyphRenderer"}],"right":[{"id":"f0287b62-19e8-48fd-843a-1c3bbefc5b0f","type":"LinearAxis"}],"title":{"id":"da95bcbf-954c-4692-a311-e9aafc386cfd","type":"Title"},"tool_events":{"id":"dae81dca-bc97-498e-9e2a-63886775929e","type":"ToolEvents"},"toolbar":{"id":"216c945b-dd25-42a0-8325-e1a735a2263a","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"b07b82ac-8594-4937-b97c-836afcc0c4f5","type":"DataRange1d"},"y_range":{"id":"d92e475b-5253-42fb-ac51-8b095bc48a6a","type":"Range1d"}},"id":"8469a516-5a4b-42d8-b873-ad6d94772921","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"bd4aaa67-2389-4da5-8f9b-4d23e628c350","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6f9815f9-d5ae-4044-b7e2-8a012c5ea3cc","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"6f9815f9-d5ae-4044-b7e2-8a012c5ea3cc","type":"BoxAnnotation"},"plot":{"id":"8469a516-5a4b-42d8-b873-ad6d94772921","subtype":"Figure","type":"Plot"}},"id":"b027a9ea-8f7a-4b0b-a07f-f5f43d6ad2d6","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"5af3b256-42d1-46f7-a26b-543d68d417 ...

# %% [markdown]
# This still looks like a linear switch between the two means.  This seem a littles strange.  Lets see how this changes if we change the relative size of the distributions?  Let change the mean of the slow group back to the original value, $m_2 = 12.0$, and adjust the size of the groups so $n_1=40$ and $n_2=60$ people.

# %%
m2 = 12.0
n1 = 40.0
n2 = 60.0
n = n1 + n2

y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n
y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n
y = y1 + y2

p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="059f6811-9521-4f23-aaa7-289900e88cf1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("059f6811-9521-4f23-aaa7-289900e88cf1").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("059f6811-9521-4f23-aaa7-289900e88cf1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '059f6811-9521-4f23-aaa7-289900e88cf1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d73804ba-56ef-4227-a066-9b3d09400f99":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"f490a385-1417-4d70-8813-86f6e8c18f32","type":"ColumnDataSource"},{"attributes":{"label":{"value":"p fast"},"renderers":[{"id":"2080db5c-7100-4ab8-b2e7-36528b1a5909","type":"GlyphRenderer"}]},"id":"0cf38538-5f5d-41ab-8b09-ab8dd888d590","type":"LegendItem"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"b6ee735f-9c85-4d99-ae79-8a7a6a69ab0d","type":"BasicTickFormatter"},"plot":{"id":"2b2c096c-016b-4906-b7f7-63f45c3f4980","subtype":"Figure","type":"Plot"},"ticker":{"id":"f6dc0209-c6ad-41a3-b264-efe090a3294e","type":"BasicTicker"}},"id":"4856623f-f9a2-4344-81eb-f40442d3e3d3","type":"LinearAxis"},{"attributes":{},"id":"aeae69be-a84a-4376-b5e1-1bfc3dd41a4c","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"fast group"},"renderers":[{"id":"f39c3577-2ec8-4472-9987-96f5e13bd5ef","type":"GlyphRenderer"}]},"id":"3290b173-7e4c-4621-98b3-1f5a1b54a747","type":"LegendItem"},{"attributes":{"below":[{"id":"4856623f-f9a2-4344-81eb-f40442d3e3d3","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"d326fe0c-b28f-4356-a6c7-5ee493523a06","type":"Range1d"}},"left":[{"id":"c46b28bc-554e-4cfa-8833-2c49da8fd321","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"4856623f-f9a2-4344-81eb-f40442d3e3d3","type":"LinearAxis"},{"id":"4fd0baa4-c6d0-4039-9689-bb9156e19866","type":"Grid"},{"id":"c46b28bc-554e-4cfa-8833-2c49da8fd321","type":"LinearAxis"},{"id":"2ad44462-15a6-4f07-a3f5-5025ad6efeb1","type":"Grid"},{"id":"26a114d6-63fd-42ec-adbf-2982d3501801","type":"BoxAnnotation"},{"id":"c97f07e7-75bf-4c84-af65-f099e1bca808","type":"LinearAxis"},{"id":"db590c03-1d96-4e8b-9dd9-b915bcab4a6a","type":"Legend"},{"id":"11c4b5e2-94fd-418b-b8d7-7f4289596d8e","type":"GlyphRenderer"},{"id":"f39c3577-2ec8-4472-9987-96f5e13bd5ef","type":"GlyphRenderer"},{"id":"05281360-71eb-41df-abc6-4f44f8cba129","type":"GlyphRenderer"},{"id":"2080db5c-7100-4ab8-b2e7-36528b1a5909","type":"GlyphRenderer"},{"id":"2b97ad3b-d367-4c33-abeb-3f542c205387","type":"GlyphRenderer"}],"right":[{"id":"c97f07e7-75bf-4c84-af65-f099e1bca808","type":"LinearAxis"}],"title":{"id":"114b428b-94a9-4fc6-992d-4eaac82d3c98","type":"Title"},"tool_events":{"id":"16feb8c0-8b4e-49f2-8114-51a41474f020","type":"ToolEvents"},"toolbar":{"id":"777853db-23af-41d6-9e65-84413261da8f","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"6bbc7265-090e-429c-bb43-453b9c80b451","type":"DataRange1d"},"y_range":{"id":"217148d6-6308-42a7-98da-11d3ab20d4d7","type":"Range1d"}},"id":"2b2c096c-016b-4906-b7f7-63f45c3f4980","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"16feb8c0-8b4e-49f2-8114-51a41474f020","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"2b2c096c-016b-4906-b7f7-63f45c3f4980","subtype":"Figure","type":"Plot"},"ticker":{"id":"8d9c1526-e529-45f8-9ac2-19a254db1b8e","type":"BasicTicker"}},"id":"2ad44462-15a6-4f07-a3f5-5025ad6efeb1","type":"Grid"},{"attributes":{"plot":{"id":"2b2c096c-016b-4906-b7f7-63f45c3f4980","subtype":"Figure","type":"Plot"}},"id":"2259b37c-86d0-4cb2-bd56-1cba3e68161e","type":"ResetTool"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"11c4b5e2-94fd-418b-b8d7-7f4289596d8e","type":"GlyphRenderer"}]},"id":"a102e42c-a0f3-4353-a431-67c09b9d97e8","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4109bd89-7ba1-443a-92cf-8adf3aa6c14a","type":"Line"},{"attributes":{"plot":{"id":"2b2c096c-016b-4906-b7f7-63f45c3f4980","subtype":"Figure","type":"Plot"}},"id":"c28d6831-d5d2-4722-abc7-50c63e399987","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9b09019-51bd-4066-ad1d-b ...

# %% [markdown]
# This shows that adjusting the verifies that the linear switch was a coincidence of our selection.  I am still considering if this implementation of the relative size is appropriate.
#
# In a more general sense, while the approach considered so far provides a switch between 0 and 1 for the times that occur between the two distributions, it does not apply what is know about a normal distribution and the probability of being a certain distance from the mean.  As a more concrete example, there is a finite probability, small as it may be in this case, that a runner from the slow group would run faster than the mean for the fast group.  We can apply what know about a Gaussian distribution to account for this.
#
# Lets reset the group sizes to the original $n_1 = 20$ and $n_2 = 80$.

# %%
n1 = 20.0
n2 = 80.0
n = n1 + n2

y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n
y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n
y = y1 + y2

p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2bb5b4e0-550a-40e4-bc8c-90e41a45d2fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2bb5b4e0-550a-40e4-bc8c-90e41a45d2fe").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2bb5b4e0-550a-40e4-bc8c-90e41a45d2fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2bb5b4e0-550a-40e4-bc8c-90e41a45d2fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"74bfdcb5-232e-41bd-b6a4-e2185f5a7200":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"80621eae-b472-478f-bae1-2594003d0ceb","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"7debf254-e412-4408-a8ff-6a8c32b2263c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e2b3cbf5-f1e6-4c9d-8c3f-f1143b55d5f8","type":"BasicTicker"}},"id":"7fe86b1a-1926-495c-9e55-33ed101427e9","type":"Grid"},{"attributes":{"plot":{"id":"7debf254-e412-4408-a8ff-6a8c32b2263c","subtype":"Figure","type":"Plot"}},"id":"5b741884-2743-4fa5-9304-d713d754ff3c","type":"ResetTool"},{"attributes":{"data_source":{"id":"6c152dde-8b23-4228-8947-d3dab370e763","type":"ColumnDataSource"},"glyph":{"id":"03bfba15-537d-4848-a5f5-cd3781edac01","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c9315285-28c0-41c2-a191-6314d592b651","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"efdcfeab-d5fb-4805-b931-2690018c6942","type":"GlyphRenderer"},{"attributes":{"label":{"value":"p slow"},"renderers":[{"id":"efdcfeab-d5fb-4805-b931-2690018c6942","type":"GlyphRenderer"}]},"id":"c766b1d1-9cb9-4e3f-a4d6-917e394cc84f","type":"LegendItem"},{"attributes":{"label":{"value":"fast group"},"renderers":[{"id":"d5790f22-ed16-4b3c-a6c1-f03af1461fb8","type":"GlyphRenderer"}]},"id":"902a55de-2117-4429-9a55-6ddc8c7d654f","type":"LegendItem"},{"attributes":{"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"03bfba15-537d-4848-a5f5-cd3781edac01","type":"Line"},{"attributes":{},"id":"3c921d3d-3d87-4af1-8bc4-91e39acb11b6","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"3a483744-927d-4adb-9fe2-56c0528745b4","type":"ColumnDataSource"},"glyph":{"id":"80621eae-b472-478f-bae1-2594003d0ceb","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"df246dfc-e38a-4385-b8a3-530a838c73e2","type":"Line"},"selection_glyph":null},"id":"f9e16068-8ec9-4d5c-842a-b4baccb9ac0a","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1f417129-871e-410d-a29a-963400b3bbab","type":"Line"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"3c921d3d-3d87-4af1-8bc4-91e39acb11b6","type":"BasicTickFormatter"},"plot":{"id":"7debf254-e412-4408-a8ff-6a8c32b2263c","subtype":"Figure","type":"Plot"},"ticker":{"id":"c2c53b93-b48f-4b19-89b2-e1aa9361a618","type":"BasicTicker"}},"id":"6c7ef493-be58-4662-b94c-a6a477ffe2b4","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9315285-28c0-41c2-a191-6314d592b651","type":"Line"},{"attributes":{"below":[{"id":"6c7ef493-be58-4662-b94c-a6a477ffe2b4","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"c067499b-548c-4026-bcc9-8eb8954a56d8","type":"Range1d"}},"left":[{"id":"908722b3-ab9d-4dc3-92bf-17316893ad44","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"6c7ef493-be58-4662-b94c-a6a477ffe2b4","type":"LinearAxis"},{"id":"94e6b0f1-4810-468a-b505-35ceb281efa0","type":"Grid"},{"id":"908722b3-ab9d-4dc3-92bf-17316893ad44","type":"LinearAxis"},{"id":"7fe86b1a-1926-495c-9e55-33ed101427e9","type":"Grid"},{"id":"23f4f5d8-8a20-4dc8-8eb6-55e0e414e016","type":"BoxAnnotation"},{"id":"bc2b104e-722d-4228-ad35-235a8ee06cd6","type":"LinearAxis"},{"id":"477ab2e7-5082-4401-a08d-4083432b0dc4","type":"Legend"},{"id":"f9e16068-8ec9-4d5c-842a-b4baccb9ac0a","type":"GlyphRenderer"},{"id":"d5790f22-ed16-4b3c-a6c1-f03af1461fb8","type":"GlyphRenderer"},{"id":"31e58022-6e38-46e5-84b8-94d7d0662841","type":"GlyphRenderer"},{"id":"401e27d9-b167-4aaf-b2dc-cc76b6e93885","type":"GlyphRenderer"},{"id":"efdcfeab-d5fb-4805-b931-2690018c6942","type":"GlyphRenderer"}],"right":[{"id":"bc2b104e-722d-4228-ad35-235a8ee06cd6","type":"LinearAxis"}],"title":{"id":"55efaaa3-07fe-45ff-a4dd-18be76af5638","type":"Title"},"tool_events":{"id":"8c8a04d8-dfe5-429b-8819-cd ...

# %% [markdown]
# Now lets calculate the probability a runner would have a given time for each distribution.  To do this, we will use [`scipy.stats.cdf`](https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.stats.norm.html), the [cumulative distribution function](https://en.wikipedia.org/wiki/Cumulative_distribution_function), taking the difference of probabilities between a small $\delta t$.

# %%
x_lower = x - dx / 2
x_upper = x + dx / 2
pd1 = (scipy.stats.norm.cdf(x_upper, loc=m1, scale=s1) - 
       scipy.stats.norm.cdf(x_lower, loc=m1, scale=s1)) * n1 / n
pd2 = (scipy.stats.norm.cdf(x_upper, loc=m2, scale=s2) - 
       scipy.stats.norm.cdf(x_lower, loc=m2, scale=s2)) * n2 / n

# %% [markdown]
# Summing each of these probability distributions should give us the percent of the total population in each group.

# %%
atol = 0.001  # absolute tolerance
assert np.allclose(pd1.sum(), n1 / n, atol=atol)
assert np.allclose(pd2.sum(), n2 / n, atol=atol)

# %% [markdown]
# Now we can consider the unlabelled runner, comparing the likelihoods he is in each group.  This will take the form
# $$
# p_\text{fast} = \dfrac{pd_1(t)}{pd_1(t) + pd_2(t)}
# $$
# where $pd_1(t)$ and $pd_2(t)$ are the probabilities a member of the fast and slow group would respectively have a time, $t$.

# %%
p1_v2 = pd1 / (pd1 + pd2)
p2_v2 = 1 - p1_v2

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v2, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v2, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cfe02fdf-dea6-4ae8-ad91-c24d2f80c6e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cfe02fdf-dea6-4ae8-ad91-c24d2f80c6e4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cfe02fdf-dea6-4ae8-ad91-c24d2f80c6e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cfe02fdf-dea6-4ae8-ad91-c24d2f80c6e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9aa07ead-7aa8-4ebe-bf66-51819d33bdc1":{"roots":{"references":[{"attributes":{"overlay":{"id":"851a4785-9c37-43d6-a9bc-5b32a3cb98a9","type":"BoxAnnotation"},"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"}},"id":"95cb4895-9152-4dc1-ae84-847b91bc893a","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"511a4480-b527-4aeb-8b5f-e37a923b0a45","type":"ColumnDataSource"},"glyph":{"id":"625d6fc4-467f-48c7-ba73-c541c7ea2085","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"84f47bf5-d00c-46be-8903-e20ce2b1f84a","type":"Line"},"selection_glyph":null},"id":"016650b7-1bef-4729-971c-0b44dc6093a3","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea41acdc-c5a1-4675-9ad1-8c098f956e06","type":"BasicTicker"}},"id":"b647f41e-7930-408a-9c03-b004e1af714f","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"},"ticker":{"id":"f8558ef3-5805-4c24-ad82-c3f76a7a14bf","type":"BasicTicker"}},"id":"cabdbd9c-84fc-4f88-8d2f-e69a32439bf6","type":"Grid"},{"attributes":{"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"}},"id":"8c169379-fc60-40cf-8e47-f7c00fc9d5a1","type":"SaveTool"},{"attributes":{},"id":"f8558ef3-5805-4c24-ad82-c3f76a7a14bf","type":"BasicTicker"},{"attributes":{},"id":"85b35630-5b9c-4aab-b1a6-c2cf7932b4eb","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":"73229c27-b60c-415e-b46e-b53d623018f0","type":"LegendItem"},{"id":"13df656b-00e6-4180-8357-27704da64f6d","type":"LegendItem"},{"id":"d5fc089f-7fd2-4f13-8d97-b5732bc88100","type":"LegendItem"},{"id":"2e381e80-60f2-496a-951e-40f155d6cf90","type":"LegendItem"},{"id":"06cd08fa-e4f7-4bb4-af67-c9c0dbe83595","type":"LegendItem"}],"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"}},"id":"c51530dd-333c-4499-993a-a7ca85b74b70","type":"Legend"},{"attributes":{"callback":null,"end":1.02},"id":"d18daaa5-5edd-457f-a03e-5d4f64d6e6dd","type":"Range1d"},{"attributes":{"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"}},"id":"468f1be0-a951-4683-ba6b-1a9f8381fd37","type":"HelpTool"},{"attributes":{"label":{"value":"p slow"},"renderers":[{"id":"33f81163-dac6-4fb5-afa0-13fb7ea013da","type":"GlyphRenderer"}]},"id":"06cd08fa-e4f7-4bb4-af67-c9c0dbe83595","type":"LegendItem"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"625d6fc4-467f-48c7-ba73-c541c7ea2085","type":"Line"},{"attributes":{},"id":"755d3062-69f0-442d-a0b4-9b04baf69aec","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"340aaf59-5977-437c-91a6-c56e70aaed35","type":"GlyphRenderer"}]},"id":"73229c27-b60c-415e-b46e-b53d623018f0","type":"LegendItem"},{"attributes":{"plot":{"id":"c5420615-6f57-453e-81ac-4fe612c35538","subtype":"Figure","type":"Plot"}},"id":"91854ab4-bcda-4698-bbbf-7b24ade89091","type":"PanTool"},{"attributes":{"label":{"value":"fast group"},"renderers":[{"id":"167b782f-5991-482b-8109-6276d93074df","type":"GlyphRenderer"}]},"id":"13df656b-00e6-4180-8357-27704da64f6d","type":"LegendItem"},{"attributes":{"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a5714fe-e0ac-44a0-9966-89a3cdc78f29","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"84f47bf5-d00c-46be-8903-e20ce2b1f84a","type":"Line"},{"attributes":{"data_source":{"id":"8579c168-f374-4509-94c3-ce6e7a05beb5","type":"ColumnDataSource"},"glyph":{"id":"6a5714fe-e0ac-44a0-9966-89a3cdc78f29","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9122705f-73eb-4607-a828-5a1f8c23f845","type":"Line"},"selection_glyph":null},"id":"167b782f-5991-482b-8109-6276d93074df","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":[" ...

# %% [markdown]
# While at first this seems a bit strange (the oscillatory nature of the probability of being in the slow group), on closer inspection we see this does make sense.  A time close to mean values of the distributions would get grouped with that distribution.  The reason the probability of the slow group goes back up for the quickest times, $t < $ 4.18 min, is that group has such a wide standard deviation that the probability decays much slower than for the narrow distribution of the fast group.
#
# While the larger standard deviation makes it more likely the fastest runner did not train, we could impose a constraint to have "p fast" smoothly transition to 1 at the quickest times.  This would coorespond to the slow group having a more assymmetric distribution, more likely exhibiting a longer tail toward the slower times.

# %% [markdown]
# Lets compare my original probability and this corrected one.

# %%
p_per = bokeh.plotting.figure(width=400, height=300,
                              y_axis_label='% of People')
p_per.line(x, y, legend='combined', color=palette[0], line_width=2)
p_per.line(x, y1, legend='fast group', color=palette[1])
p_per.line(x, y2, legend='slow group', color=palette[2])

p_prob = bokeh.plotting.figure(width=400, height=300,
                               y_axis_label='Probability',
                               x_range=p_per.x_range)
p_prob.line(x, p1_v1, legend='p_v1 fast', color=palette[3])
p_prob.line(x, p2_v1, legend='p_v1 slow', color=palette[4])
p_prob.line(x, p1_v2, legend='p_v2 fast', color=palette[3], line_dash='dashed')
p_prob.line(x, p2_v2, legend='p_v2 slow', color=palette[4], line_dash='dashed')

p_diff = bokeh.plotting.figure(width=400, height=100,
                               x_axis_label='Time (m)',
                               y_axis_label='Residuals',
                               x_range=p_per.x_range)
p_diff.line(x, p1_v2-p1_v1, color=palette[3])
p_diff.line(x, p2_v2-p2_v1, color=palette[4])

p = bokeh.layouts.gridplot([[p_per], [p_prob], [p_diff]])
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="174b24a3-0b2b-4d68-adb7-80ae75b4e3b7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("174b24a3-0b2b-4d68-adb7-80ae75b4e3b7").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("174b24a3-0b2b-4d68-adb7-80ae75b4e3b7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '174b24a3-0b2b-4d68-adb7-80ae75b4e3b7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3dc845d4-c430-4759-9fc3-17b970ea5027":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"da92df70-55cd-46f1-8a45-2d54ee68f3c0","type":"Line"},{"attributes":{"plot":{"id":"94ed8f4a-267e-40e0-ad16-29c439c1f2c9","subtype":"Figure","type":"Plot"}},"id":"3c3fd42f-1e34-4fe0-b2a6-bf1b2d6e3e90","type":"SaveTool"},{"attributes":{"data_source":{"id":"f49e5133-28ae-4d31-936e-74a357cc8c76","type":"ColumnDataSource"},"glyph":{"id":"8bc6643d-cfb4-4814-9cf0-d68b13610188","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"da92df70-55cd-46f1-8a45-2d54ee68f3c0","type":"Line"},"selection_glyph":null},"id":"9a4a54d7-c2ec-47f5-a3e2-bea63ddcffea","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e91aff99-44c2-463d-bd3f-187d3f0decb3","subtype":"Figure","type":"Plot"}},"id":"9168f647-97cb-4d94-ab06-66716b900290","type":"SaveTool"},{"attributes":{"children":[{"id":"e91aff99-44c2-463d-bd3f-187d3f0decb3","subtype":"Figure","type":"Plot"}]},"id":"1f42e116-ad33-4485-99a8-d41676a92f38","type":"Row"},{"attributes":{"formatter":{"id":"4e96d658-ef14-4c6c-b3d4-78b5c8bab3d8","type":"BasicTickFormatter"},"plot":{"id":"e91aff99-44c2-463d-bd3f-187d3f0decb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"747021df-38fb-4a81-9308-3b0c481aeade","type":"BasicTicker"}},"id":"dd44855a-4e60-4c72-99ae-c6b4e142fff0","type":"LinearAxis"},{"attributes":{},"id":"1870bb02-aee9-43f9-aa0c-139ecec1e12e","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"94ed8f4a-267e-40e0-ad16-29c439c1f2c9","subtype":"Figure","type":"Plot"}]},"id":"9c44a059-f353-48ad-b9a4-b1939ff766ce","type":"Row"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4ccbcb6a-4348-4fa2-b267-af0a2b59bc1c","type":"PanTool"},{"id":"d54bbb1d-0590-47a9-b195-634d2b8f73c9","type":"WheelZoomTool"},{"id":"50b0faa4-d255-4e43-a5b8-99ab5228c08c","type":"BoxZoomTool"},{"id":"28a4b843-e5b4-41c0-abf0-932cb353f20d","type":"SaveTool"},{"id":"b1f25e3f-ce47-4fc8-8014-078649866a87","type":"ResetTool"},{"id":"55e1dc6e-8cf6-4c22-bc72-1dba80a8f5cd","type":"HelpTool"}]},"id":"16270bd4-8b87-467e-b8b4-f6bb7a53a834","type":"Toolbar"},{"attributes":{"line_color":{"value":"#d62728"},"line_dash":[6],"x":{"field":"x"},"y":{"field":"y"}},"id":"923de16a-844e-45ae-85d9-4e60b266e899","type":"Line"},{"attributes":{"data_source":{"id":"b3c77cca-bfa8-4df7-a637-eba14cd61386","type":"ColumnDataSource"},"glyph":{"id":"8ff01392-0f56-4243-8342-86296f390b76","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"86f6c3c9-df82-4ea5-a9a6-c3c1a44d93ee","type":"Line"},"selection_glyph":null},"id":"9456bcac-0b0e-463e-94cc-42154984032d","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8ff01392-0f56-4243-8342-86296f390b76","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"c8983736-606e-41bd-a26f-f59963005791","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"edd8c9ca-542a-4be1-9da0-fd2b4d1e58d5","type":"Title"},{"attributes":{"label":{"value":"fast group"},"renderers":[{"id":"8f959db6-6c58-47bf-8024-0dcfca69c895","type":"GlyphRenderer"}]},"id":"58381acd-0c69-4713-9bcf-a401f257ac3f","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"4225badb-58a8-4452-b04d-7c6a139bf7f4","type":"ColumnDataSource"},{"attributes":{"label":{"value":"p_v1 fast"},"renderers":[{"id":"197a7502-2bd5-42dc-b5dd-f830cda75c0d","type":"GlyphRenderer"}]},"id":"7c7b6f76-2604-4dbf-8c4b-3ac63138d4a5","type":"LegendItem"},{"attributes":{"plot":{"id":"94ed8f4a-267e-40e0-ad16-29c439c1f2c9","subtype":"Figure","type": ...

# %% [markdown]
# This shows a general agreement though there are some important differences.
