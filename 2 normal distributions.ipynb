# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import numpy as np
import pandas as pd

# %%
import scipy.interpolate
import scipy.stats

# %%
import bokeh.plotting
import bokeh.models  # LinearAxis 
from bokeh.palettes import Category10_10 as palette

# %%
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="780c6343-d35d-488e-a691-c732a2e0244d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Question:
# Given two normal distributions of different mean and standard deviation, consider a measurement with a value between the two means, what is the probability for it belonging to each of the two distributions?
#
# As an example, consider two groups of runners.  The first group of runners trains regularly and is in good shape.  The second group of runners does not train but still enjoy running occaisionally.  You measure how fast everyone can run the mile then calculate the mean and standard deviation for each group.  Then you find you have the time for one person but forgot to label what group they came from.  Based on their time for running the mile, what is the probability they are in the group that trains regularly?
#
# To put some numbers to this example, lets say the group that trains regularly have a mean time of 6.5 minutes with a standard deviation of 0.75 minutes and that the occasional runners have a mean time of 10 minutes with a standard devaition of 2 minutes.  Additionally, lets say there are 20 people in the faster group and 80 people in the slower group.
#
# Mean times:<br>
# $ m_1 = 6.5\,\text{min}$<br>
# $ m_2 = 12.0\,\text{min}$<br>
#
# Standard deviations:<br>
# $ s_1 = 0.75\,\text{min}$<br>
# $ s_2 = 3.0\,\text{min}$<br>
#
# Group size:<br>
# $ n_1 = 20\,\text{people}$<br>
# $ n_2 = 80\,\text{people}$<br>
#
# ## Caveat:
# Note that often a Gaussian distribution is a simplified view of a more complicated genuine distribution.  For this situation, it is much more likely that both groups of runners would have an asymmetric distribution.  We could safely expect both groups of runners, but especially the group that does not train regularly, would exhibit a longer tail for slower times.  In the following analysis, we proceed under the optimized assumption that each group can be described by a single Gaussian distribution.

# %%
m1 = 6.5
m2 = 12.0

s1 = .75
s2 = 3.0

n1 = 20
n2 = 80
n = n1 + n2

# %%
x_min = 2.0
x_max = 25.0
x = np.linspace(x_min, x_max, 200)
y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n

y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n

y = y1 + y2

p = bokeh.plotting.figure(width=400, height=300, 
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="76b1c7a0-e052-4e79-aa35-527e9220a989"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("76b1c7a0-e052-4e79-aa35-527e9220a989");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("76b1c7a0-e052-4e79-aa35-527e9220a989");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '76b1c7a0-e052-4e79-aa35-527e9220a989' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"105a131c-6805-4497-bb36-56739baac547":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"59575556-ebd4-4ee6-894e-1a7b58fc4bb3","type":"Line"},{"attributes":{"data_source":{"id":"4c20fc9a-bef0-42a8-a57a-438de302a0a9","type":"ColumnDataSource"},"glyph":{"id":"6ae0e8aa-84f2-47d8-8c8b-4e284965e9f1","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"59575556-ebd4-4ee6-894e-1a7b58fc4bb3","type":"Line"},"selection_glyph":null},"id":"3723ef6c-793f-4a4b-895b-12a0ec3492c5","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ae0e8aa-84f2-47d8-8c8b-4e284965e9f1","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"617ea736-541c-42e9-a0d7-ed8ebdab4fe0","type":"Title"},{"attributes":{},"id":"cb127b83-22b2-411f-a631-6b97e7d69b34","type":"BasicTicker"},{"attributes":{},"id":"1f28146e-cbf6-4d60-86a5-d51021e8cb41","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"c84119d8-d0c3-4ef5-a5c1-19ea3220dcd9","type":"LinearAxis"}],"left":[{"id":"a9d60342-f627-4b1e-9130-0142acf410ee","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"c84119d8-d0c3-4ef5-a5c1-19ea3220dcd9","type":"LinearAxis"},{"id":"c73a8c6b-ed66-471b-99df-fbaac82a5d4a","type":"Grid"},{"id":"a9d60342-f627-4b1e-9130-0142acf410ee","type":"LinearAxis"},{"id":"8cd31a1b-f1a4-4f1c-8a8c-967c0eee790c","type":"Grid"},{"id":"7bd80c19-e81e-490d-89e8-b5726deef3f6","type":"BoxAnnotation"},{"id":"6b1db1b5-2ec0-49b0-82e3-03217c8a0462","type":"Legend"},{"id":"3723ef6c-793f-4a4b-895b-12a0ec3492c5","type":"GlyphRenderer"},{"id":"dee5d349-c580-4eec-a8a8-3de9bf9eb798","type":"GlyphRenderer"},{"id":"26a82517-9689-4e28-8866-26f41043fdd1","type":"GlyphRenderer"}],"title":{"id":"617ea736-541c-42e9-a0d7-ed8ebdab4fe0","type":"Title"},"tool_events":{"id":"d43aaf29-49c6-4dd3-8767-ec675d614c3c","type":"ToolEvents"},"toolbar":{"id":"1c9dd2e6-e794-43a3-8140-86fada597dea","type":"Toolbar"},"x_range":{"id":"cb9dce37-f5a8-4f34-976e-c0766b3f97b2","type":"DataRange1d"},"y_range":{"id":"63c36d85-9411-4372-8a73-f771210b85ec","type":"DataRange1d"}},"id":"f85e04e6-7735-46fa-b329-4e4a0248386c","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"% of People","formatter":{"id":"412b8db5-555c-4cc6-9332-1d463cb6faee","type":"BasicTickFormatter"},"plot":{"id":"f85e04e6-7735-46fa-b329-4e4a0248386c","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb127b83-22b2-411f-a631-6b97e7d69b34","type":"BasicTicker"}},"id":"a9d60342-f627-4b1e-9130-0142acf410ee","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"4c20fc9a-bef0-42a8-a57a-438de302a0a9","type":"ColumnDataSource"},{"attributes":{},"id":"d43aaf29-49c6-4dd3-8767-ec675d614c3c","type":"ToolEvents"},{"attributes":{"callback":null},"id":"cb9dce37-f5a8-4f34-976e-c0766b3f97b2","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"601f7154-2c76-402f-a725-fbee34d66ab8","type":"PanTool"},{"id":"38629ef5-9f65-4921-825b-8d6a25494682","type":"WheelZoomTool"},{"id":"df8e3006-dcb5-478a-96b3-fbf3f3b0b129","type":"BoxZoomTool"},{"id":"cd323a6d-35ee-4c22-b71a-39dda17d6ab9","type":"SaveTool"},{"id":"ad692d9a-288f-47ac-a7e3-516ff6c443ca","type":"ResetTool"},{"id":"746fb608-7341-4a98-a241-b90cc6db3b1d","type":"HelpTool"}]},"id":"1c9dd2e6-e794-43a3-8140-86fada597dea","type":"Toolbar"},{"attributes":{"callback":null},"id":"63c36d85-9411-4372-8a73-f771210b85ec","type":"DataRange1d"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"1f28146e-cbf6-4d60-86a5-d51021e8cb41","type":"BasicTickFormatter"},"plot":{"id":"f85e04e6-7735-46fa-b329-4e4a0248386c", ...

# %% [markdown]
# If we calculate the area under the curves, we should get the percent of people in each group.

# %%
dx = x[1] - x[0]

# %%
a = dx * y.sum()
print(a)
# Out:
# 0.999674635352

# %%
a1 = dx * y1.sum()
print(a1)
# Out:
# 0.199999999882

# %%
a2 = dx * y2.sum()
print(a2)
# Out:
# 0.79967463547

# %% [markdown]
# Now lets consider the runner who was not labelled.
#
# My initial approach was to compare his time, $t$ to the means and standard distributions, calculating the difference between the means as
# $$
# \begin{align}
#   d_1 &= | t - m_1|\\
#   d_2 &= | t - m_2|
# \end{align}
# $$
# then calculate the probability of being in the fast group as
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                     &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_1 d_1}{s_1 d_1 + s_2 d_2} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                     &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$
#
# This probability will have the following distribution.

# %%
p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, 1-p1_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9b6a0372-424e-428c-b0ba-3bf4de92d7aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9b6a0372-424e-428c-b0ba-3bf4de92d7aa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9b6a0372-424e-428c-b0ba-3bf4de92d7aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9b6a0372-424e-428c-b0ba-3bf4de92d7aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d3d0539d-ec39-4654-8dcc-6c5e2206d7ac":{"roots":{"references":[{"attributes":{"callback":null,"end":1.02},"id":"831c5360-fc4a-472e-9697-2aa68fe69c54","type":"Range1d"},{"attributes":{"below":[{"id":"7791b134-d791-4e74-800c-1a4ea46bea2a","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"831c5360-fc4a-472e-9697-2aa68fe69c54","type":"Range1d"}},"left":[{"id":"859f3e8f-4a12-45a0-9efd-79836b5b9ac2","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"7791b134-d791-4e74-800c-1a4ea46bea2a","type":"LinearAxis"},{"id":"e60b7cf1-806d-434f-acbb-eb065999719d","type":"Grid"},{"id":"859f3e8f-4a12-45a0-9efd-79836b5b9ac2","type":"LinearAxis"},{"id":"2af95a89-5fd0-47d9-a76f-98ef42a91c8f","type":"Grid"},{"id":"0e4e2179-8c9e-425f-8727-1c14a1c24366","type":"BoxAnnotation"},{"id":"ddb624f6-0cc9-4191-874e-a9ebbe733b5d","type":"LinearAxis"},{"id":"a4b13454-167a-4d5b-9f16-eab9d695340e","type":"Legend"},{"id":"3d9ce48a-7b3a-44cc-be10-35bbc52b8e28","type":"GlyphRenderer"},{"id":"4857e83d-a07b-4425-8d06-f04e3dfe44be","type":"GlyphRenderer"},{"id":"f92e7095-1a3a-4ba0-9299-7d409aee94f8","type":"GlyphRenderer"},{"id":"631c2b9d-e65f-48b3-b118-e4c5b5b3fc5d","type":"GlyphRenderer"},{"id":"d494ea6c-1705-49aa-9925-8a817de8bba4","type":"GlyphRenderer"}],"right":[{"id":"ddb624f6-0cc9-4191-874e-a9ebbe733b5d","type":"LinearAxis"}],"title":{"id":"3130e2a4-95f9-4b9b-9b5d-c8d2dd6d50ff","type":"Title"},"tool_events":{"id":"d1b43839-b3c7-4f2a-8b57-0af0cbd88f7e","type":"ToolEvents"},"toolbar":{"id":"9ff809d8-3567-4214-8ab3-883f98ed38f0","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"2b00265b-419c-4ec4-899c-ba6fbdf2219b","type":"DataRange1d"},"y_range":{"id":"949b5ede-05b9-42c3-ab4b-fb8a21256608","type":"Range1d"}},"id":"8a0ea895-c51c-4f4a-91bf-65852d4737eb","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"adda747d-2236-4d3d-a117-aeafd898a7d9","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"8a0ea895-c51c-4f4a-91bf-65852d4737eb","subtype":"Figure","type":"Plot"}},"id":"200e1bb2-4bf5-4f03-8e8b-e6b625d47a34","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5718288a-1d25-40aa-b97b-77dbe2c1b908","type":"PanTool"},{"id":"33d0cb29-e6c8-482f-a4c2-f244142e1525","type":"WheelZoomTool"},{"id":"ef65f361-1944-4654-b196-cc0aeb070098","type":"BoxZoomTool"},{"id":"6489f623-1808-4b32-ae17-421b790f704a","type":"SaveTool"},{"id":"200e1bb2-4bf5-4f03-8e8b-e6b625d47a34","type":"ResetTool"},{"id":"9731c35d-efa3-485b-b852-ba38f64bcc1d","type":"HelpTool"}]},"id":"9ff809d8-3567-4214-8ab3-883f98ed38f0","type":"Toolbar"},{"attributes":{"callback":null,"end":0.15},"id":"949b5ede-05b9-42c3-ab4b-fb8a21256608","type":"Range1d"},{"attributes":{"plot":{"id":"8a0ea895-c51c-4f4a-91bf-65852d4737eb","subtype":"Figure","type":"Plot"}},"id":"9731c35d-efa3-485b-b852-ba38f64bcc1d","type":"HelpTool"},{"attributes":{"callback":null},"id":"2b00265b-419c-4ec4-899c-ba6fbdf2219b","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"52cacc9f-0a75-488e-b3ab-2635da5c6e71","type":"Line"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"539c75ca-eb08-465e-ab08-ee432321fa2a","type":"BasicTickFormatter"},"plot":{"id":"8a0ea895-c51c-4f4a-91bf-65852d4737eb","subtype":"Figure","type":"Plot"},"ticker":{"id":"bc697c59-f7ac-4247-ae18-ecbd6b671f7b","type":"BasicTicker"}},"id":"7791b134-d791-4e74-800c-1a4ea46bea2a","type":"LinearAxis"},{"attributes":{},"id":"bc697c59-f7ac-4247-ae18-ecbd6b671f7b","type":"BasicTicker"},{"attributes":{"plot":{"id":"8a0ea895-c51c-4f4a-91bf-65852d4737eb","subtype":"Figure","type":"Plot"},"ticker":{"id":"bc697c59-f7ac-4247-ae18-ecbd6b671f7b","type":"BasicTicker"}},"id":"e60b7cf ...

# %% [markdown]
# This is clearly wrong as the crossover from being more likely to be in fast group is much too close to the slow group.  Lets see what happens when we switch the standard deviations to use
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                      &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_2 d_1}{s_2 d_1 + s_1 d_2} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                      &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$
#
# With this change, the probability will have the following distribution.

# %%
p1_v1[mask] = 1 - s2 * d1[mask] / (s2 * d1[mask] + s1 * d2[mask])
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="234510a4-df6c-47a6-a4ee-7807700e4da9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("234510a4-df6c-47a6-a4ee-7807700e4da9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("234510a4-df6c-47a6-a4ee-7807700e4da9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '234510a4-df6c-47a6-a4ee-7807700e4da9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a9b2fccc-0f97-4dac-9fb7-3858a2a337a3":{"roots":{"references":[{"attributes":{"callback":null},"id":"2e4b01d0-bddf-4afa-8497-a9f413a1324a","type":"DataRange1d"},{"attributes":{},"id":"621a84d6-f0e5-41d1-a21e-40220bcfd24e","type":"BasicTicker"},{"attributes":{"below":[{"id":"00fbd32c-bc57-4f53-ab04-ec84908aa6d0","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"3aebb03d-dd76-40d8-8cda-45fd062e2d36","type":"Range1d"}},"left":[{"id":"5c22c27e-3c26-44f0-a160-155d1d660e59","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"00fbd32c-bc57-4f53-ab04-ec84908aa6d0","type":"LinearAxis"},{"id":"81ec77b2-97b9-4d94-a61f-617e87a48a22","type":"Grid"},{"id":"5c22c27e-3c26-44f0-a160-155d1d660e59","type":"LinearAxis"},{"id":"e41cbfc5-875a-475e-b2bd-121ed4936579","type":"Grid"},{"id":"89367441-bde0-4b8c-9fc9-6b75f9f56177","type":"BoxAnnotation"},{"id":"bddf6ca0-0d62-4046-ade8-5bada4ef462b","type":"LinearAxis"},{"id":"b4339c79-53dd-4b79-8536-a471ccc23b1c","type":"Legend"},{"id":"dec95e5a-302e-4ae1-88ff-7bfd3ba376e7","type":"GlyphRenderer"},{"id":"c268d90e-a4ba-4c5b-92c0-644b5aa9cf58","type":"GlyphRenderer"},{"id":"5875940a-968c-4c2e-97a1-3ea417170950","type":"GlyphRenderer"},{"id":"5cc63be5-c4e0-4f3f-8b66-0f58324cb1c3","type":"GlyphRenderer"},{"id":"062177c2-e33b-4f8a-b4b4-43404f95c1a3","type":"GlyphRenderer"}],"right":[{"id":"bddf6ca0-0d62-4046-ade8-5bada4ef462b","type":"LinearAxis"}],"title":{"id":"70814f36-4416-4a2c-93b4-0838524f8c92","type":"Title"},"tool_events":{"id":"7aa6c807-887a-461e-8793-4fb0fb05805c","type":"ToolEvents"},"toolbar":{"id":"30034fec-7a5d-4db2-8d52-9f461958317e","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"2e4b01d0-bddf-4afa-8497-a9f413a1324a","type":"DataRange1d"},"y_range":{"id":"4eb81c02-7348-4db5-a651-91c4e57a98bf","type":"Range1d"}},"id":"68d07025-0607-4b4b-824c-b0ba0ed43b15","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"e2016fa3-ada6-4e75-8bed-e35f18683185","type":"BasicTickFormatter"},"plot":{"id":"68d07025-0607-4b4b-824c-b0ba0ed43b15","subtype":"Figure","type":"Plot"},"ticker":{"id":"621a84d6-f0e5-41d1-a21e-40220bcfd24e","type":"BasicTicker"}},"id":"00fbd32c-bc57-4f53-ab04-ec84908aa6d0","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"84e701de-3188-4509-8338-98ed2f299893","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5e169504-20bc-423d-ba95-b9ea2c332272","type":"PanTool"},{"id":"fd49c14e-20ee-4baf-afde-af1bdbfc0cdb","type":"WheelZoomTool"},{"id":"2dde7d9c-5968-42a4-ae5b-26fe9369a139","type":"BoxZoomTool"},{"id":"aab2d394-11a9-4fdf-94d8-ef397f941109","type":"SaveTool"},{"id":"d90b5f11-9938-4d89-a2b8-a662e491c3a5","type":"ResetTool"},{"id":"60670bde-d8fb-4daf-bdc7-b77bf5f21d00","type":"HelpTool"}]},"id":"30034fec-7a5d-4db2-8d52-9f461958317e","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"68d07025-0607-4b4b-824c-b0ba0ed43b15","subtype":"Figure","type":"Plot"},"ticker":{"id":"54672753-082b-4aa2-b165-0919dcddb1b9","type":"BasicTicker"}},"id":"e41cbfc5-875a-475e-b2bd-121ed4936579","type":"Grid"},{"attributes":{"axis_label":"Probability","formatter":{"id":"6cd7a2ae-87f6-471c-bf66-ab09799312db","type":"BasicTickFormatter"},"plot":{"id":"68d07025-0607-4b4b-824c-b0ba0ed43b15","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3d81126-3ded-4369-ae8d-b5eb6b60c174","type":"BasicTicker"},"y_range_name":"prob"},"id":"bddf6ca0-0d62-4046-ade8-5bada4ef462b","type":"LinearAxis"},{"attributes":{},"id":"54672753-082b-4aa2-b165-0919dcddb1b9","type":"BasicTicker"},{"attributes":{"axis_label":"% of People","formatter":{"id":"a23c002d-8080-4941-abe2-f2fa980bb76c","type":"BasicTickFormatter"},"plot":{"id":"68d07025-0607-4b4b-824c-b0ba0ed43b15","subtype" ...

# %% [markdown]
# This seems more reasonable but I did not take into account the relative difference in the size of the groups.  Lets add a scale factor related to this difference.

# %% [markdown]
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                      &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_2 d_1 \frac{n_1}{n}}{s_2 d_1 \frac{n_1}{n} + s_1 d_2 \frac{n_2}{n}} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                      &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$

# %%
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bdfa66c3-d1d4-474f-ab54-365db157ba16"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bdfa66c3-d1d4-474f-ab54-365db157ba16");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bdfa66c3-d1d4-474f-ab54-365db157ba16");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bdfa66c3-d1d4-474f-ab54-365db157ba16' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cedb3a70-2d5f-404e-8994-5e2a62b22e29":{"roots":{"references":[{"attributes":{"axis_label":"% of People","formatter":{"id":"aca832e4-0169-4e2f-9c33-6d905346e42f","type":"BasicTickFormatter"},"plot":{"id":"d345da83-a6fe-4102-82b9-38c9e861d46f","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7358389-53f6-439c-8693-3e822c526fd9","type":"BasicTicker"}},"id":"e0d39f17-70b4-4e1e-ae38-a00963ab6cbe","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"d092bce4-8958-44d3-b3d6-68ac93cfd9c1","type":"Title"},{"attributes":{"callback":null,"end":0.15},"id":"dbf53c4b-ab48-49ff-9b36-8e8441c1b403","type":"Range1d"},{"attributes":{"plot":{"id":"d345da83-a6fe-4102-82b9-38c9e861d46f","subtype":"Figure","type":"Plot"}},"id":"552e3e49-3ed8-4bc2-ae7a-86cfab77861c","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"d345da83-a6fe-4102-82b9-38c9e861d46f","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7358389-53f6-439c-8693-3e822c526fd9","type":"BasicTicker"}},"id":"7cbf8818-a8d3-4add-8007-a3be8ecebbde","type":"Grid"},{"attributes":{},"id":"06905721-f496-41ed-a2f8-7ee16f7f2d8c","type":"BasicTickFormatter"},{"attributes":{},"id":"cce1cbe5-d906-4bef-a71f-f8d5c9ec276e","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5d3b801a-47e9-433d-b1e4-4c27d05ea7ef","type":"Line"},{"attributes":{"below":[{"id":"ad806457-70c5-4459-ac93-335e1219a708","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"e2653b2b-b46e-4239-8841-2afd67c47f79","type":"Range1d"}},"left":[{"id":"e0d39f17-70b4-4e1e-ae38-a00963ab6cbe","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"ad806457-70c5-4459-ac93-335e1219a708","type":"LinearAxis"},{"id":"1b12699f-fb05-40eb-b43f-bda901c17ca7","type":"Grid"},{"id":"e0d39f17-70b4-4e1e-ae38-a00963ab6cbe","type":"LinearAxis"},{"id":"7cbf8818-a8d3-4add-8007-a3be8ecebbde","type":"Grid"},{"id":"10a57105-7766-46e5-b6d9-fe4f458d8e67","type":"BoxAnnotation"},{"id":"d5827fc0-c56b-4585-906a-aa43c3d83b5f","type":"LinearAxis"},{"id":"b6d52c27-84b0-4912-8e1f-d2dd8bae166e","type":"Legend"},{"id":"087f23a1-09d4-4264-8d96-d14a5ef04697","type":"GlyphRenderer"},{"id":"b4bbce4e-2801-46da-b341-b7719e8bf823","type":"GlyphRenderer"},{"id":"fddef835-ab96-43e7-98b2-90f1f8bf5bb9","type":"GlyphRenderer"},{"id":"c3f5a199-f4ba-4b4b-b1c1-502d49efc369","type":"GlyphRenderer"},{"id":"cb400450-9b0b-46d4-a432-ca7d3abe30d0","type":"GlyphRenderer"}],"right":[{"id":"d5827fc0-c56b-4585-906a-aa43c3d83b5f","type":"LinearAxis"}],"title":{"id":"d092bce4-8958-44d3-b3d6-68ac93cfd9c1","type":"Title"},"tool_events":{"id":"9da5996e-8f1b-44af-91a6-756a0cf18f7c","type":"ToolEvents"},"toolbar":{"id":"43488ca5-173a-48e8-80d0-47f4ca1079ae","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"dbe7d34d-8f7b-4e9e-87bb-430ccbb38d55","type":"DataRange1d"},"y_range":{"id":"dbf53c4b-ab48-49ff-9b36-8e8441c1b403","type":"Range1d"}},"id":"d345da83-a6fe-4102-82b9-38c9e861d46f","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"087f23a1-09d4-4264-8d96-d14a5ef04697","type":"GlyphRenderer"}]},"id":"9cc01a3e-491b-47ee-b6c0-d6cc5b365ecb","type":"LegendItem"},{"attributes":{"callback":null},"id":"dbe7d34d-8f7b-4e9e-87bb-430ccbb38d55","type":"DataRange1d"},{"attributes":{},"id":"aca832e4-0169-4e2f-9c33-6d905346e42f","type":"BasicTickFormatter"},{"attributes":{},"id":"862d94d9-74c1-49ac-8ec1-3fda5c62a926","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"079ffa4c-df67-4780-88af-94b4149928b6","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":1.02},"id":"e2653b2b-b46e-4239-8841-2afd67c47f79","type":"Range1d"},{"attributes":{"plot":{"id":"d345da83-a6fe-4102-82b9-38c9e861d46f","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b8c2c10-73ca-464a ...

# %% [markdown]
# This looks like a linear switch between the two means.  How does this change if we change one of the mean values?  Let make $m_2=15.0$ minutes.

# %%
m2 = 15.0

y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n
y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n
y = y1 + y2

p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cc9d9cad-54bf-4019-bb63-b0f11d729262"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cc9d9cad-54bf-4019-bb63-b0f11d729262");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc9d9cad-54bf-4019-bb63-b0f11d729262");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc9d9cad-54bf-4019-bb63-b0f11d729262' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25117519-0bb1-4a26-95d3-7dedd4fd28a3":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a887c4d4-a4c8-4fb8-bf01-6f6315a97724","type":"Line"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"90eb2d4b-07bd-4829-ab9b-f9a421dde043","type":"Line"},{"attributes":{"data_source":{"id":"481e25d0-0dbb-4944-9351-13cf2902a10f","type":"ColumnDataSource"},"glyph":{"id":"d227223e-3d49-4f8a-b27e-ebe6ab975fb2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a887c4d4-a4c8-4fb8-bf01-6f6315a97724","type":"Line"},"selection_glyph":null},"id":"4f95dd99-7d3a-4d31-9d39-61dcd38f845f","type":"GlyphRenderer"},{"attributes":{"label":{"value":"slow group"},"renderers":[{"id":"4f95dd99-7d3a-4d31-9d39-61dcd38f845f","type":"GlyphRenderer"}]},"id":"f19dfd7e-423b-46a6-a833-76d7d4134ca7","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"dc794e03-0b78-4dad-a627-e1783261239d","type":"ColumnDataSource"},{"attributes":{"axis_label":"% of People","formatter":{"id":"060dc049-c150-4c60-8f40-ff2b7dd7683a","type":"BasicTickFormatter"},"plot":{"id":"84783784-be90-4330-88bc-22d4e49dbc4e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4835d465-457d-4d88-8711-748c4e07adda","type":"BasicTicker"}},"id":"361b3290-2d43-4de5-9dce-debfbb9b3ed2","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3787d3ad-a05f-4257-94e7-5baacbc299b0","type":"ColumnDataSource"},"glyph":{"id":"90eb2d4b-07bd-4829-ab9b-f9a421dde043","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"913fbff9-948d-45e2-8bd6-64e3dc9b8b4c","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"0e69925c-40fe-41b5-a486-081d6da155dd","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"913fbff9-948d-45e2-8bd6-64e3dc9b8b4c","type":"Line"},{"attributes":{"label":{"value":"p fast"},"renderers":[{"id":"0e69925c-40fe-41b5-a486-081d6da155dd","type":"GlyphRenderer"}]},"id":"1d720856-befa-4143-aa6e-bf2d80850a7a","type":"LegendItem"},{"attributes":{"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b77742a-670f-4002-8ee2-34a64572ef19","type":"Line"},{"attributes":{"data_source":{"id":"dc794e03-0b78-4dad-a627-e1783261239d","type":"ColumnDataSource"},"glyph":{"id":"5b77742a-670f-4002-8ee2-34a64572ef19","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1a433059-ab26-4cef-98af-c4617f5786af","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"029f90f0-2437-47d7-8c06-959d9efe71f8","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a433059-ab26-4cef-98af-c4617f5786af","type":"Line"},{"attributes":{"label":{"value":"p slow"},"renderers":[{"id":"029f90f0-2437-47d7-8c06-959d9efe71f8","type":"GlyphRenderer"}]},"id":"bcba13bc-44f9-4981-a938-a35c8d88ae64","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c538a3e-32c2-43e4-b88e-0629cb43b899","type":"Line"},{"attributes":{},"id":"a91ab9ee-963e-41b7-9fdf-56032a5ba787","type":"BasicTickFormatter"},{"attributes":{},"id":"f6f5ad19-d5b0-4820-85be-bf88d43cb303","type":"BasicTicker"},{"attributes":{"below":[{"id":"b7dd8833-02e7-450e-8ba5-297d4f759013","type":"LinearAxis"}],"extra_y_ranges":{"prob":{"id":"bae3202a-51f2-496c-95c1-95677e2f580f","type":"Range1d"}},"left":[{"id":"361b3290-2d43-4de5-9dce-debfbb9b3ed2","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"b7dd8833-02e7-450e-8ba5-297d4f759013","type":"LinearAxis"},{"id":"48b0c422-9397-46a ...

# %% [markdown]
# This still looks like a linear switch between the two means.  This seem a littles strange.  Lets see how this changes if we change the relative size of the distributions?  Let change the mean of the slow group back to the original value, $m_2 = 12.0$, and adjust the size of the groups so $n_1=40$ and $n_2=60$ people.

# %%
m2 = 12.0
n1 = 40.0
n2 = 60.0
n = n1 + n2

y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n
y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n
y = y1 + y2

p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="55d9c601-c7f6-408b-845f-ad19aba93dbe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("55d9c601-c7f6-408b-845f-ad19aba93dbe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55d9c601-c7f6-408b-845f-ad19aba93dbe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55d9c601-c7f6-408b-845f-ad19aba93dbe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"076e241b-2ec0-499e-8ff3-e8716cecd865":{"roots":{"references":[{"attributes":{"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a22aca33-7a8d-4a95-bf69-dd97ffa18c3e","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a4d99d8b-8b87-4e7c-a396-7a172308b3aa","type":"Line"},{"attributes":{"data_source":{"id":"18bb6279-2101-4158-8abe-23de4775118a","type":"ColumnDataSource"},"glyph":{"id":"a22aca33-7a8d-4a95-bf69-dd97ffa18c3e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a4d99d8b-8b87-4e7c-a396-7a172308b3aa","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"2f6b99e0-40da-4590-9235-750291850bba","type":"GlyphRenderer"},{"attributes":{"label":{"value":"p slow"},"renderers":[{"id":"2f6b99e0-40da-4590-9235-750291850bba","type":"GlyphRenderer"}]},"id":"edfd8682-f2c0-47e4-8697-cc749101fb4f","type":"LegendItem"},{"attributes":{"plot":{"id":"a827da09-8c2f-421c-9917-b3238064fa9e","subtype":"Figure","type":"Plot"}},"id":"e7012d64-02fc-4308-ab7b-8a365c299ee0","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"400d51b3-14f1-4f37-a4ea-5bbc27184a71","type":"ColumnDataSource"},{"attributes":{"label":{"value":"slow group"},"renderers":[{"id":"175477cd-83c3-4711-967a-f48f5c02b8a1","type":"GlyphRenderer"}]},"id":"6634d1e9-d8f6-46c0-ae4b-b9dccb4bc6b9","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b1bee3e5-d71e-4ab7-a3ba-2910af9ad5bd","type":"Line"},{"attributes":{},"id":"0e8d5ebb-92e0-45d4-bc47-e75e076665e8","type":"BasicTicker"},{"attributes":{"data_source":{"id":"400d51b3-14f1-4f37-a4ea-5bbc27184a71","type":"ColumnDataSource"},"glyph":{"id":"949060e9-0bd3-4b71-acf5-5de3c1c1f756","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b1bee3e5-d71e-4ab7-a3ba-2910af9ad5bd","type":"Line"},"selection_glyph":null},"id":"175477cd-83c3-4711-967a-f48f5c02b8a1","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"0c57a050-585d-4193-ad5f-1e428761947f","type":"BoxAnnotation"},"plot":{"id":"a827da09-8c2f-421c-9917-b3238064fa9e","subtype":"Figure","type":"Plot"}},"id":"c007f301-a092-40f1-996f-2fc473547295","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"6b6f76d8-161e-4830-8c03-b00673a2f762","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"2f20b402-fb53-4097-ac12-18e232cebe20","type":"Title"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"b4555408-a32c-4e00-b2fb-d03875186787","type":"BasicTickFormatter"},"plot":{"id":"a827da09-8c2f-421c-9917-b3238064fa9e","subtype":"Figure","type":"Plot"},"ticker":{"id":"0e8d5ebb-92e0-45d4-bc47-e75e076665e8","type":"BasicTicker"}},"id":"f7abccbb-6aba-41ca-9f13-19e9fdb295d6","type":"LinearAxis"},{"attributes":{"plot":{"id":"a827da09-8c2f-421c-9917-b3238064fa9e","subtype":"Figure","type":"Plot"},"ticker":{"id":"0e8d5ebb-92e0-45d4-bc47-e75e076665e8","type":"BasicTicker"}},"id":"8a7a8217-eb25-4a6a-bdff-921004e826c2","type":"Grid"},{"attributes":{"callback":null,"end":0.15},"id":"787d55f5-40fb-4307-af6a-38f3885bd948","type":"Range1d"},{"attributes":{"data_source":{"id":"ca891aa4-a9fc-4fb9-a1e3-16061297d69b","type":"ColumnDataSource"},"glyph":{"id":"d5e94d99-f85c-4dc4-831e-b34e4ddba059","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1867d489-b9f5-40af-82df-d6ffb26f53cf","type":"Line"},"selection_glyph":null},"id":"4c3ff4d9-2c99-4b65-be63-4e409ffbff53","type":"GlyphRenderer"},{"attributes":{},"id":"b4555408-a32c-4e00-b2fb-d03875186787","type":"BasicT ...

# %% [markdown]
# This shows that adjusting the verifies that the linear switch was a coincidence of our selection.  I am still considering if this implementation of the relative size is appropriate.
#
# In a more general sense, while the approach considered so far provides a switch between 0 and 1 for the times that occur between the two distributions, it does not apply what is know about a normal distribution and the probability of being a certain distance from the mean.  As a more concrete example, there is a finite probability, small as it may be in this case, that a runner from the slow group would run faster than the mean for the fast group.  We can apply what know about a Gaussian distribution to account for this.
#
# Lets reset the group sizes to the original $n_1 = 20$ and $n_2 = 80$.

# %%
n1 = 20.0
n2 = 80.0
n = n1 + n2

y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n
y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n
y = y1 + y2

p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])
p1_v1[mask] = 1 - s2 * d1[mask] * n1 / n / (s2 * d1[mask] * n1 / n + s1 * d2[mask] * n2 / n)
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ed490b54-158b-4726-aa1e-9d4a503427a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ed490b54-158b-4726-aa1e-9d4a503427a9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ed490b54-158b-4726-aa1e-9d4a503427a9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ed490b54-158b-4726-aa1e-9d4a503427a9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cce0bf90-e208-4732-a3f9-dbad82fbf6df":{"roots":{"references":[{"attributes":{"callback":null,"end":0.15},"id":"79d5b51a-8f32-4ee8-a7fb-f2d71a366167","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"d50b9a98-8693-4d7e-a5cb-2ad4c5476d15","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c90017b8-2eda-4880-9ca2-824be458e7dc","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"eec13a0f-715c-4e2e-ac8c-dedbb3790807","type":"PanTool"},{"id":"8d8e2b36-ae3d-45e4-bf9c-e31fe546f106","type":"WheelZoomTool"},{"id":"b0f92702-fdab-4793-b9e0-bddc90ad2ab8","type":"BoxZoomTool"},{"id":"153051e7-d42b-49f2-b164-71ac3b93d507","type":"SaveTool"},{"id":"411a12c3-41bd-4bb4-bfb3-a8d2695a5bde","type":"ResetTool"},{"id":"ac8e4869-9f67-434f-b009-9757bdd6da89","type":"HelpTool"}]},"id":"0411f7cb-3b38-4bef-83c1-566a806e7a5e","type":"Toolbar"},{"attributes":{},"id":"e6035b80-bf1f-42ba-9534-62821a34f5d3","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"52aa4a09-8c00-4a76-9d94-eedb42ad7e25","type":"Line"},{"attributes":{"items":[{"id":"cade9f9b-d359-4d00-a37f-13b8e9096659","type":"LegendItem"},{"id":"f362d731-a407-4039-b7ff-9a54bfe97db0","type":"LegendItem"},{"id":"6e55c72f-7b7e-4d57-b0c4-670e3dc8b601","type":"LegendItem"},{"id":"64ab6ddd-b9a2-4287-ab58-330c722fd670","type":"LegendItem"},{"id":"866f0e23-52df-4587-9b2b-ee3949888b7a","type":"LegendItem"}],"plot":{"id":"f8171cfd-e73a-466a-95e3-c2fae56102e9","subtype":"Figure","type":"Plot"}},"id":"a94523cf-d40e-44cb-b839-4662e924980b","type":"Legend"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"93eac3f6-7b4e-44c7-a314-f9cf757a2b54","type":"BasicTickFormatter"},"plot":{"id":"f8171cfd-e73a-466a-95e3-c2fae56102e9","subtype":"Figure","type":"Plot"},"ticker":{"id":"e6035b80-bf1f-42ba-9534-62821a34f5d3","type":"BasicTicker"}},"id":"bdd1eb19-9faf-4e3b-af94-0e45c907db73","type":"LinearAxis"},{"attributes":{},"id":"93eac3f6-7b4e-44c7-a314-f9cf757a2b54","type":"BasicTickFormatter"},{"attributes":{},"id":"720fc3b2-fe12-4ba2-96d4-69a55cde60a5","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"38983f82-1ea4-4458-80e1-913ed43cbb77","type":"Line"},{"attributes":{"callback":null},"id":"29b565e7-9dce-468a-a5c5-1e83bdf87470","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e73c0c5-da98-4318-934b-7be62d326168","type":"Line"},{"attributes":{"callback":null,"end":1.02},"id":"7cd44b53-6ba7-4d91-b71c-7976f02182ac","type":"Range1d"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb70da94-ebf2-455c-9de7-87f4fd5e7d3d","type":"Line"},{"attributes":{"data_source":{"id":"3682b176-9316-40c3-ba42-7a8ddc340df4","type":"ColumnDataSource"},"glyph":{"id":"38983f82-1ea4-4458-80e1-913ed43cbb77","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5fa5bd29-9ed7-4d93-b05d-be74f0eb9229","type":"Line"},"selection_glyph":null},"id":"2849b457-9311-48c3-8069-0140bf90d95b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"c5d502db-8b90-40a5-81f1-ffcb0526a134","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8edf2124-32cf-4027-9475-9f7f5848c721","type":"Line"},{"attributes":{"data_source":{"id":"b8775b4e-80fb-45c3-9788-83551cabab98","type":"Co ...

# %% [markdown]
# Now lets calculate the probability a runner would have a given time for each distribution.  To do this, we will use [`scipy.stats.cdf`](https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.stats.norm.html), the [cumulative distribution function](https://en.wikipedia.org/wiki/Cumulative_distribution_function), taking the difference of probabilities between a small $\delta t$.

# %%
x_lower = x - dx / 2
x_upper = x + dx / 2
pd1 = (scipy.stats.norm.cdf(x_upper, loc=m1, scale=s1) - 
       scipy.stats.norm.cdf(x_lower, loc=m1, scale=s1)) * n1 / n
pd2 = (scipy.stats.norm.cdf(x_upper, loc=m2, scale=s2) - 
       scipy.stats.norm.cdf(x_lower, loc=m2, scale=s2)) * n2 / n

# %% [markdown]
# Summing each of these probability distributions should give us the percent of the total population in each group.

# %%
atol = 0.001  # absolute tolerance
assert np.allclose(pd1.sum(), n1 / n, atol=atol)
assert np.allclose(pd2.sum(), n2 / n, atol=atol)

# %% [markdown]
# Now we can consider the unlabelled runner, comparing the likelihoods he is in each group.  This will take the form
# $$
# p_\text{fast} = \dfrac{pd_1(t)}{pd_1(t) + pd_2(t)}
# $$
# where $pd_1(t)$ and $pd_2(t)$ are the probabilities a member of the fast and slow group would respectively have a time, $t$.

# %%
p1_v2 = pd1 / (pd1 + pd2)
p2_v2 = 1 - p1_v2

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v2, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v2, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6ebe3e07-ec5e-4931-baf1-33fac3e09ed2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6ebe3e07-ec5e-4931-baf1-33fac3e09ed2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6ebe3e07-ec5e-4931-baf1-33fac3e09ed2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6ebe3e07-ec5e-4931-baf1-33fac3e09ed2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f4aacde9-0a0d-4e83-a455-0ccf16bee27a":{"roots":{"references":[{"attributes":{"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cdebf8c-b62f-40f6-bac9-8dba34fad8db","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"dd343fd6-15d0-4908-a5d7-09cbb811a688","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5b1fcab5-e51a-42f4-9dc5-9f1f39c86f9c","type":"ColumnDataSource"},"glyph":{"id":"b25c5e48-4596-466a-a610-1085e893d5c0","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ea8151ab-dd98-4b8c-a8cf-2729120f3bdd","type":"Line"},"selection_glyph":null},"id":"fbfb4b39-6ea9-4533-be2d-0ce44c777534","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b25c5e48-4596-466a-a610-1085e893d5c0","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea8151ab-dd98-4b8c-a8cf-2729120f3bdd","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"aa5a1be1-de2b-48e0-b117-7a00b5312eb2","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"861132d9-55a8-4f28-94ea-281aa093f4ad","type":"Line"},{"attributes":{"items":[{"id":"5c5d7580-db97-4e40-a9e7-dcc7688b8e14","type":"LegendItem"},{"id":"aa4712ef-1acc-44d8-949e-89eb0ae52bac","type":"LegendItem"},{"id":"d003206d-5e07-4d75-9305-b9dc5602f71e","type":"LegendItem"},{"id":"42f978c5-b0a4-42d6-b5e8-a2113a8b52b6","type":"LegendItem"},{"id":"98beaac1-f028-4301-a1bc-3379352b1f55","type":"LegendItem"}],"plot":{"id":"f3db7a0e-75e0-4ba1-a678-d024f1d3efe9","subtype":"Figure","type":"Plot"}},"id":"edacf93e-e6e4-4cd5-bfbb-dd08fcf361b8","type":"Legend"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"aa898d39-f022-492b-a18c-e9b954e727f0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"dd343fd6-15d0-4908-a5d7-09cbb811a688","type":"ColumnDataSource"},"glyph":{"id":"861132d9-55a8-4f28-94ea-281aa093f4ad","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4cb0ca92-f86d-4ca3-9347-431a4113a9bb","type":"Line"},"selection_glyph":null,"y_range_name":"prob"},"id":"73fce1c8-5f69-454d-bf1f-a49f38b63a73","type":"GlyphRenderer"},{"attributes":{},"id":"8122655a-eac3-4852-9e1c-0e85a3c1f951","type":"BasicTicker"},{"attributes":{"callback":null,"end":0.15},"id":"43068816-6bf1-462c-9ef9-e3b12232fc54","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c7121ea-b26f-4800-bf7b-230e13bbca43","type":"Line"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"23fc3c3f-c72d-4b2d-97b9-27f50cacc646","type":"GlyphRenderer"}]},"id":"5c5d7580-db97-4e40-a9e7-dcc7688b8e14","type":"LegendItem"},{"attributes":{"label":{"value":"p slow"},"renderers":[{"id":"5162abfe-a94c-460b-abac-c20cf6d55c0d","type":"GlyphRenderer"}]},"id":"98beaac1-f028-4301-a1bc-3379352b1f55","type":"LegendItem"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"75c42c8f-5522-46ad-8be5-b907d1d9beb2","type":"Line"},{"attributes":{"callback":null},"id":"dd75e8f1-a973-4d45-8d12-b538ae15f79e","type":"DataRange1d"},{"attributes":{"plot":{"id":"f3db7a0e-75e0-4ba1-a678-d024f1d3efe9","subtype":"Figure","type":"Plot"}},"id":"a20d94b1-8e6e-4366-bcd9-2cbef92c6eda","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value" ...

# %% [markdown]
# While at first this seems a bit strange (the oscillatory nature of the probability of being in the slow group), on closer inspection we see this does make sense.  A time close to mean values of the distributions would get grouped with that distribution.  The reason the probability of the slow group goes back up for the quickest times, $t < $ 4.18 min, is that group has such a wide standard deviation that the probability decays much slower than for the narrow distribution of the fast group.
#
# While the larger standard deviation makes it more likely the fastest runner did not train, we could impose a constraint to have "p fast" smoothly transition to 1 at the quickest times.  This would coorespond to the slow group having a more assymmetric distribution, more likely exhibiting a longer tail toward the slower times.

# %% [markdown]
# Lets compare my original probability and this corrected one.

# %%
p_per = bokeh.plotting.figure(width=400, height=300,
                              y_axis_label='% of People')
p_per.line(x, y, legend='combined', color=palette[0], line_width=2)
p_per.line(x, y1, legend='fast group', color=palette[1])
p_per.line(x, y2, legend='slow group', color=palette[2])

p_prob = bokeh.plotting.figure(width=400, height=300,
                               y_axis_label='Probability',
                               x_range=p_per.x_range)
p_prob.line(x, p1_v1, legend='p_v1 fast', color=palette[3])
p_prob.line(x, p2_v1, legend='p_v1 slow', color=palette[4])
p_prob.line(x, p1_v2, legend='p_v2 fast', color=palette[3], line_dash='dashed')
p_prob.line(x, p2_v2, legend='p_v2 slow', color=palette[4], line_dash='dashed')

p_diff = bokeh.plotting.figure(width=400, height=100,
                               x_axis_label='Time (m)',
                               y_axis_label='Residuals',
                               x_range=p_per.x_range)
p_diff.line(x, p1_v2-p1_v1, color=palette[3])
p_diff.line(x, p2_v2-p2_v1, color=palette[4])

p = bokeh.layouts.gridplot([[p_per], [p_prob], [p_diff]])
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a68200a5-e484-480e-8c5f-3761e25b7f00"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a68200a5-e484-480e-8c5f-3761e25b7f00");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a68200a5-e484-480e-8c5f-3761e25b7f00");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a68200a5-e484-480e-8c5f-3761e25b7f00' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c55afe5d-b5b0-48f9-b9fd-f4b4391414ef":{"roots":{"references":[{"attributes":{"callback":null},"id":"7fc24d15-df75-411b-b9c0-17a7d9b71092","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3992d258-f825-44a0-ab83-fc4d0e565b51","type":"Line"},{"attributes":{},"id":"21a6e852-72bf-41b4-86a2-6a1653b5010f","type":"BasicTicker"},{"attributes":{"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"},"ticker":{"id":"21a6e852-72bf-41b4-86a2-6a1653b5010f","type":"BasicTicker"}},"id":"74ded3cb-f30b-4ac4-b09f-a5bf6ee8482b","type":"Grid"},{"attributes":{"axis_label":"Probability","formatter":{"id":"1bec035f-5169-42ec-967d-1fc3c75a65f2","type":"BasicTickFormatter"},"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"},"ticker":{"id":"1e7d1b1c-c737-4f24-b24f-f91404952e86","type":"BasicTicker"}},"id":"8ec248f2-fb2f-4cc4-aa0d-eab0838a15e4","type":"LinearAxis"},{"attributes":{},"id":"1e7d1b1c-c737-4f24-b24f-f91404952e86","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"},"ticker":{"id":"1e7d1b1c-c737-4f24-b24f-f91404952e86","type":"BasicTicker"}},"id":"4fa67e9f-7450-4926-af07-2d437fd9471a","type":"Grid"},{"attributes":{"data_source":{"id":"4194753b-4eba-471d-bf44-260ee259a78f","type":"ColumnDataSource"},"glyph":{"id":"c792b362-01fb-4f51-b46e-cd19779e5f88","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3992d258-f825-44a0-ab83-fc4d0e565b51","type":"Line"},"selection_glyph":null},"id":"dfd26fb9-e815-465c-95c5-31477c91b552","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c792b362-01fb-4f51-b46e-cd19779e5f88","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"9d26b441-5c4f-4cdb-b1a9-9b1ef34d8247","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"28498f85-c245-44b7-bceb-e152421a1e23","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"}},"id":"4a9f8417-dca0-4bf0-91b6-7bc245206bda","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"018dc0d8-5cf1-4c84-9ac5-6fb5c14c0ace","type":"Title"},{"attributes":{"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"}},"id":"7fbf0292-0eaa-4998-978c-08fb7a961c05","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"28498f85-c245-44b7-bceb-e152421a1e23","type":"BoxAnnotation"},"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"}},"id":"e0728295-a791-4528-8759-6f3841b9375c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"}},"id":"4558a58b-a614-4720-8cd1-ae701aa857cf","type":"SaveTool"},{"attributes":{"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"}},"id":"81b2568b-1b52-40e4-8c6d-6205a2927529","type":"ResetTool"},{"attributes":{"plot":{"id":"41a60427-e379-40a7-a8f9-dda24cbbb6db","subtype":"Figure","type":"Plot"}},"id":"63dc0c09-eabd-46d1-a18e-da6d6132584b","type":"HelpTool"},{"attributes":{"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7754814a-4a9b-4f79-92c5-9e31a5ca18cd","type":"Line"},{"attributes":{"plot":{"id":"cc7a0841-d205-4611-8923-57ad41933d70","subtype":"Figure","type":"Plot"}},"id":"c0b485a2-8480-4c1b-be68-432ca4e9d54e", ...

# %% [markdown]
# This shows a general agreement though there are some important differences. In particular, the time at which the probability switches from one group to the other is around 7.5 minutes rather than just over 9 minutes.  This agrees much better with what we would expect looking at the two distributions.
