# %%
import numpy as np
import pandas as pd

# %%
import scipy.interpolate
import scipy.stats

# %%
import bokeh.plotting
import bokeh.models  # LinearAxis 
from bokeh.palettes import Category10_10 as palette

# %%
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b9a55d0e-e7a3-4ff4-8757-e00c3916a8b2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Question:
# Given two normal distributions of different mean and standard deviation, consider a measurement with a value between the two means, what is the probability for it belonging to each of the two distributions?
#
# As an example, consider two groups of runners.  The first group of runners trains regularly and is in good shape.  The second group of runners does not train but still enjoy running occaisionally.  You measure how fast everyone can run the mile then calculate the mean and standard deviation for each group.  Then you find you have the time for one person but forgot to label what group they came from.  Based on their time for running the mile, what is the probability they are in the group that trains regularly?
#
# To put some numbers to this example, lets say the group that trains regularly have a mean time of 6.5 minutes with a standard deviation of 1 minute and that the occasional runners have a mean time of 10 minutes with a standard devaition of 2 minutes.  Additionally, lets say there are 20 people in the faster group and 80 people in the slower group.
#
# Mean times:<br>
# $ m_1 = 6.5\,\text{min}$<br>
# $ m_2 = 12.0\,\text{min}$<br>
#
# Standard deviations:<br>
# $ s_1 = 0.75\,\text{min}$<br>
# $ s_2 = 3.0\,\text{min}$<br>
#
# Group size:<br>
# $ n_1 = 20\,\text{people}$<br>
# $ n_2 = 80\,\text{people}$<br>

# %%
m1 = 6.5
m2 = 12.0

s1 = .75
s2 = 3.0

n1 = 20
n2 = 80
n = n1 + n2

# %%
x_min = 2.0
x_max = 25.0
x = np.linspace(x_min, x_max, 200)
y1 = scipy.stats.norm.pdf(x, loc=m1, scale=s1) * n1 / n

y2 = scipy.stats.norm.pdf(x, loc=m2, scale=s2) * n2 / n

y = y1 + y2

p = bokeh.plotting.figure(width=400, height=300, 
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fcc52e93-1b1d-4874-ba55-6879a22db4f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fcc52e93-1b1d-4874-ba55-6879a22db4f1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fcc52e93-1b1d-4874-ba55-6879a22db4f1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fcc52e93-1b1d-4874-ba55-6879a22db4f1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d3050036-5110-432c-a30a-9f2cd74c1cd4":{"roots":{"references":[{"attributes":{"data_source":{"id":"e71b7b97-cf78-4720-acdc-669a2697c66d","type":"ColumnDataSource"},"glyph":{"id":"b39bbb77-7432-4c6a-9c3a-719233dae02c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a51332e3-fed4-4269-ae66-8f2ed80cfb8f","type":"Line"},"selection_glyph":null},"id":"8e757455-6e0f-4dcb-9129-d3d92d37d808","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"a757cfe3-c178-4693-8e8f-56ee4f14f5f4","type":"LinearAxis"}],"left":[{"id":"3a0c9c4b-df8f-45d6-9a6f-03b8309d3fc2","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"a757cfe3-c178-4693-8e8f-56ee4f14f5f4","type":"LinearAxis"},{"id":"4f1d99d4-46cb-4300-bbc6-9e296168df5b","type":"Grid"},{"id":"3a0c9c4b-df8f-45d6-9a6f-03b8309d3fc2","type":"LinearAxis"},{"id":"cf49552d-389b-4101-bed8-3852b8a94daa","type":"Grid"},{"id":"6a14ef88-50d4-4c12-bf16-85fd30dd29e5","type":"BoxAnnotation"},{"id":"8ce4e9e9-fc12-49b3-99a4-be6e0e8b6ec8","type":"Legend"},{"id":"8e757455-6e0f-4dcb-9129-d3d92d37d808","type":"GlyphRenderer"},{"id":"6438c8c9-1454-4afd-9cc9-91dd84dd56f2","type":"GlyphRenderer"},{"id":"3da190c3-0cab-4127-b3ca-8cf7f2677a12","type":"GlyphRenderer"}],"title":{"id":"86810076-934c-4547-9f33-39524114ebbb","type":"Title"},"tool_events":{"id":"583ca79a-ab54-4883-b650-e6fae090f721","type":"ToolEvents"},"toolbar":{"id":"9b3cb727-477b-4a5f-94d3-ec2a16a04912","type":"Toolbar"},"x_range":{"id":"36b93bac-94a5-4df4-ac48-a134500e0868","type":"DataRange1d"},"y_range":{"id":"8288b534-46ac-4b13-b37a-140a3a57aa9e","type":"DataRange1d"}},"id":"ccf972fb-211e-4c95-a091-ff850dc9fcbf","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"e71b7b97-cf78-4720-acdc-669a2697c66d","type":"ColumnDataSource"},{"attributes":{},"id":"583ca79a-ab54-4883-b650-e6fae090f721","type":"ToolEvents"},{"attributes":{"callback":null},"id":"36b93bac-94a5-4df4-ac48-a134500e0868","type":"DataRange1d"},{"attributes":{},"id":"46d15aab-8a30-4cc0-ad52-a2606955022e","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6f37dac6-2695-49aa-b9d4-07510be9face","type":"PanTool"},{"id":"db5f8e4f-60da-4dac-856c-2789df92500d","type":"WheelZoomTool"},{"id":"07525b44-3661-4875-bcbe-45ec8a6d8879","type":"BoxZoomTool"},{"id":"96891bb0-5a86-4ce1-ac2b-da1ed6a3baf9","type":"SaveTool"},{"id":"4992f9eb-1ea7-4402-96c7-e6da573a6fbb","type":"ResetTool"},{"id":"bf374619-2258-4a39-a686-47cd9225cd3a","type":"HelpTool"}]},"id":"9b3cb727-477b-4a5f-94d3-ec2a16a04912","type":"Toolbar"},{"attributes":{"callback":null},"id":"8288b534-46ac-4b13-b37a-140a3a57aa9e","type":"DataRange1d"},{"attributes":{},"id":"9e535aaf-119d-4e44-9424-a7452cd6f975","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"9e535aaf-119d-4e44-9424-a7452cd6f975","type":"BasicTickFormatter"},"plot":{"id":"ccf972fb-211e-4c95-a091-ff850dc9fcbf","subtype":"Figure","type":"Plot"},"ticker":{"id":"6fd16802-5223-49fd-ac9f-1c5c9928c1dd","type":"BasicTicker"}},"id":"a757cfe3-c178-4693-8e8f-56ee4f14f5f4","type":"LinearAxis"},{"attributes":{},"id":"6fd16802-5223-49fd-ac9f-1c5c9928c1dd","type":"BasicTicker"},{"attributes":{"plot":{"id":"ccf972fb-211e-4c95-a091-ff850dc9fcbf","subtype":"Figure","type":"Plot"},"ticker":{"id":"6fd16802-5223-49fd-ac9f-1c5c9928c1dd","type":"BasicTicker"}},"id":"4f1d99d4-46cb-4300-bbc6-9e296168df5b","type":"Grid"},{"attributes":{"axis_label":"% of People","formatter":{"id":"46d15aab-8a30-4cc0-ad52-a2606955022e","type":"BasicTickFormatter"},"plot":{"id":"ccf972fb-211e-4c95-a091-ff850dc9fcbf","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b2ff73c-44d1-4614-b90b-78f40481d383","type":"BasicTicker"}},"id":"3a0c9c4b-df8f-45d6- ...

# %% [markdown]
# If we calculate the area under the curves, we should get the percent of people in each group.

# %%
dx = x[1] - x[0]

# %%
a = dx * y.sum()
print(a)
# Out:
# 0.999674635352

# %%
a1 = dx * y1.sum()
print(a1)
# Out:
# 0.199999999882

# %%
a2 = dx * y2.sum()
print(a2)
# Out:
# 0.79967463547

# %% [markdown]
# Now lets consider the runner who was not labelled.
#
# My initial approach was to compare his time, $t$ to the means and standard distributions, calculating the difference between the means as
# $$
# \begin{align}
#   d_1 &= | t - m_1|\\
#   d_2 &= | t - m_2|
# \end{align}
# $$
# then calculate the probability of being in the fast group as
# $$
# p_\text{fast} =\left\{ \begin{array}{cl}
#                1                                     &\mbox{ if $t < m_1$} \\
#                1 - \dfrac{s_1 d_1}{s_1 d_1 + s_2 d_2} &\mbox{ if $m_1 <= t < m_2$}\\
#                0                                     &\mbox{ if $m_2 <= t$}
#                \end{array} \right.
# $$
#
# This probability will have the following distribution.

# %%
p1_v1 = np.zeros_like(x)
p1_v1[x < m1] = 1

d1 = np.abs(x - m1)
d2 = np.abs(x - m2)

mask = np.logical_and(m1 < x, x < m2)
p1_v1[mask] = 1 - s1 * d1[mask] / (s1 * d1[mask] + s2 * d2[mask])

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, 1-p1_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4588105e-b6f8-4f53-85bf-747a1131bd33"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4588105e-b6f8-4f53-85bf-747a1131bd33");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4588105e-b6f8-4f53-85bf-747a1131bd33");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4588105e-b6f8-4f53-85bf-747a1131bd33' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4bbbca0d-7117-4de2-bde3-86b3aa62fe9a":{"roots":{"references":[{"attributes":{},"id":"3dba9450-e237-4da7-aeee-4ae9951ce294","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"61e8baee-9793-405b-ad3d-046d0fb65c2e","type":"Line"},{"attributes":{"axis_label":"Time (m)","formatter":{"id":"3dba9450-e237-4da7-aeee-4ae9951ce294","type":"BasicTickFormatter"},"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"5684a904-f9f1-442a-a971-42049c37a33a","type":"BasicTicker"}},"id":"0fc04362-de00-445c-ab62-108edc200036","type":"LinearAxis"},{"attributes":{},"id":"5684a904-f9f1-442a-a971-42049c37a33a","type":"BasicTicker"},{"attributes":{"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"5684a904-f9f1-442a-a971-42049c37a33a","type":"BasicTicker"}},"id":"5630faac-9132-41f8-bd8a-64b5e9243902","type":"Grid"},{"attributes":{"axis_label":"% of People","formatter":{"id":"6f54f8e5-24fa-4615-a2a4-dabf76a2e989","type":"BasicTickFormatter"},"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a001e689-2926-4045-9d33-4f56939194c8","type":"BasicTicker"}},"id":"1c833177-86a6-4bf9-b253-a5b79ae522e6","type":"LinearAxis"},{"attributes":{},"id":"a001e689-2926-4045-9d33-4f56939194c8","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a001e689-2926-4045-9d33-4f56939194c8","type":"BasicTicker"}},"id":"a5220e16-e6b3-43a4-802f-9cf0c2e406c6","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"98c0a338-a743-4fd3-90bc-e15284615b23","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":0.15},"id":"f5a7878e-192e-4084-9770-2f32adfc584e","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1f43a03-b838-4702-9308-250aee04cfd6","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8c691d28-222c-433c-807d-4b98a56a5453","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"}},"id":"87965c90-f5fe-4dfc-afbd-e7d09c5a50d5","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"03d8f21f-09a5-41ec-9cd7-a8b6a0286533","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"}},"id":"9d2de0f1-c06e-4149-9323-d3a910de53c8","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"8c691d28-222c-433c-807d-4b98a56a5453","type":"BoxAnnotation"},"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"}},"id":"fd70045b-6d10-44b9-9cb5-1adff921bd79","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"}},"id":"f0abde51-d457-4e49-9b6b-d2285f5bdcc3","type":"SaveTool"},{"attributes":{"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"}},"id":"5082b8c3-ee3e-4315-951b-cfe120aba29c","type":"ResetTool"},{"attributes":{"plot":{"id":"383343f9-573a-482c-8f88-72a6155d58c8","subtype":"Figure","type":"Plot"}},"id":"cee7b525-a202-4117-813c-93cf8cc8fa97","type":"HelpTool"},{"attributes":{ ...

# %% [markdown]
# This is clearly wrong as the crossover from being more likely to be in fast group is much too close to the slow group.  Lets see what happens when we switch the standard deviations.

# %%
p1_v1[mask] = 1 - s2 * d1[mask] / (s2 * d1[mask] + s1 * d2[mask])
p2_v1 = 1 - p1_v1

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v1, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v1, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a8aaa6f2-c426-4c38-a998-1cd3271fec93"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a8aaa6f2-c426-4c38-a998-1cd3271fec93");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a8aaa6f2-c426-4c38-a998-1cd3271fec93");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a8aaa6f2-c426-4c38-a998-1cd3271fec93' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fc05c154-f3a1-41dc-81b9-4f4d86cc4bb2":{"roots":{"references":[{"attributes":{"axis_label":"Time (m)","formatter":{"id":"1ac6c883-3b48-4909-b76b-a198d01baaba","type":"BasicTickFormatter"},"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"},"ticker":{"id":"4609be13-8391-46ac-a11b-a51e765586cf","type":"BasicTicker"}},"id":"95eee450-1498-46ac-8b61-8c70c6f358c9","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b5a85804-580e-4dee-9172-d2018db9e0ae","type":"Line"},{"attributes":{"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"}},"id":"8f20c155-fe49-4b67-9886-201f41de3b92","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"b6c25769-e1b2-46f2-aa01-0721f110f634","type":"ColumnDataSource"},{"attributes":{},"id":"d309fd3d-5176-4a1c-83ce-a9f49df40dbe","type":"ToolEvents"},{"attributes":{"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"}},"id":"b25d343d-265c-46d3-8c2d-84cfb1509798","type":"SaveTool"},{"attributes":{"overlay":{"id":"dd0a5759-9c86-41c4-88fa-0ecd9a6a13a6","type":"BoxAnnotation"},"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"}},"id":"d895db19-ef9d-4563-825b-680e30674966","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"85a9578b-806a-430b-88ef-15717565e749","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"}},"id":"c1047c61-4af6-44b7-9ac6-fe69573c9d31","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"}},"id":"5358a03d-a8c7-4549-8e2a-d1bee6d3e089","type":"HelpTool"},{"attributes":{"plot":{"id":"da9a19b7-2a2d-4f02-90cf-7c8d300040c7","subtype":"Figure","type":"Plot"}},"id":"b2d4ba3c-8e51-4005-a300-5daf07fecff9","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"8047e805-638e-4b59-bd7f-c44612e65199","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f8e4313-509e-4a68-8696-6c37ebe6a799","type":"Line"},{"attributes":{"data_source":{"id":"cdef0213-e54b-4b2f-a993-38b0268ff2ed","type":"ColumnDataSource"},"glyph":{"id":"5bb730f3-6c81-434e-9358-0c3401212927","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0f8e4313-509e-4a68-8696-6c37ebe6a799","type":"Line"},"selection_glyph":null},"id":"669b2bc1-3b0f-4359-9dee-9bd53dc53e33","type":"GlyphRenderer"},{"attributes":{"label":{"value":"fast group"},"renderers":[{"id":"12cd9bef-158a-4145-bd3e-78b33feebe9f","type":"GlyphRenderer"}]},"id":"5960dcd0-921b-4705-b06e-6a87398442b1","type":"LegendItem"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5bb730f3-6c81-434e-9358-0c3401212927","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"2bf632c7-1b30-4be3-ae30-82d4fa2bf8f1","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7306eca5-0fbb-4b12-8f1c-81a4ee838487","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units": ...

# %% [markdown]
# This seems more reasonable but this approach does not apply what is know about a normal distribution and the probability of being a certain distance from the mean.  More concretely, there is a finite probability, small as it may be in this case, that a runner from the slow group would run faster than the mean for the fast group.
#
# Lets calculate the probability a runner would have a given time for each distribution.  To do this, we will use [`scipy.stats.cdf`](https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.stats.norm.html), the [cumulative distribution function](https://en.wikipedia.org/wiki/Cumulative_distribution_function), taking the difference of probabilities between a small $\delta t$.

# %%
x_lower = x - dx / 2
x_upper = x + dx / 2
pd1 = (scipy.stats.norm.cdf(x_upper, loc=m1, scale=s1) - 
       scipy.stats.norm.cdf(x_lower, loc=m1, scale=s1))
pd2 = (scipy.stats.norm.cdf(x_upper, loc=m2, scale=s2) - 
       scipy.stats.norm.cdf(x_lower, loc=m2, scale=s2))

# %% [markdown]
# Summing each of these probability distributions should give us 1.

# %%
atol = 0.001  # absolute tolerance
assert np.allclose(pd1.sum(), 1, atol=atol)
assert np.allclose(pd2.sum(), 1, atol=atol)

# %% [markdown]
# Now we can consider the unlabelled runner, comparing the likelihoods he is in each group.  This will take the form
# $$
# p_\text{fast} = \dfrac{pd_1(t)}{pd_1(t) + pd_2(t)}
# $$
# where $pd_1(t)$ and $pd_2(t)$ are the probabilities a member of the fast and slow group would respectively have a time, $t$.

# %%
p1_v2 = pd1 / (pd1 + pd2)
p2_v2 = 1 - p1_v2

# %%
p = bokeh.plotting.figure(width=400, height=300, toolbar_location='above',
                          x_axis_label='Time (m)',
                          y_axis_label='% of People')
p.extra_y_ranges = {'prob': bokeh.models.Range1d(start=0, end=1.02)}
p.add_layout(bokeh.models.LinearAxis(y_range_name='prob', 
                                     axis_label='Probability'), 'right')

p.y_range = bokeh.models.Range1d(start=0, end=0.15)
p.line(x, y, legend='combined', color=palette[0], line_width=2)
p.line(x, y1, legend='fast group', color=palette[1])
p.line(x, y2, legend='slow group', color=palette[2])
p.line(x, p1_v2, legend='p fast', color=palette[3], y_range_name='prob')
p.line(x, p2_v2, legend='p slow', color=palette[4], y_range_name='prob')

p.legend.location = 'top_right'

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="696ddd07-b838-4540-81d3-5084de7a20ed"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("696ddd07-b838-4540-81d3-5084de7a20ed");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("696ddd07-b838-4540-81d3-5084de7a20ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '696ddd07-b838-4540-81d3-5084de7a20ed' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2e1928d3-c277-4fc1-830b-5063a730a7d0":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"98ef9a4a-3458-4df1-8395-b891e07fed6e","type":"Title"},{"attributes":{"plot":{"id":"d59ee073-d6eb-4058-9e01-2e7615e5b626","subtype":"Figure","type":"Plot"}},"id":"4c1d81ce-b883-4be6-82c7-3fdcba6f9747","type":"HelpTool"},{"attributes":{},"id":"cfb3fcce-5280-4611-9db9-ba462bc4ba6f","type":"BasicTickFormatter"},{"attributes":{},"id":"51370e09-504d-41a0-a211-900b20fb620e","type":"BasicTickFormatter"},{"attributes":{},"id":"eb757101-d247-4c24-94ab-4c93aa0c2b0f","type":"BasicTickFormatter"},{"attributes":{},"id":"c431bee4-3293-49f4-99ed-532a609d2aab","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94acf577-99d2-476e-b53b-69283b130dae","type":"Line"},{"attributes":{"data_source":{"id":"87b6c71d-f8c8-410d-b987-dce5cb11d892","type":"ColumnDataSource"},"glyph":{"id":"8bad924f-0cd5-422a-a0ee-9903dcdcde44","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"94acf577-99d2-476e-b53b-69283b130dae","type":"Line"},"selection_glyph":null},"id":"577dc1d5-d39d-4520-8eb5-01ce134c8380","type":"GlyphRenderer"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"f81216b1-b188-4fa2-bef9-220762b30ad2","type":"GlyphRenderer"}]},"id":"8789d147-1e52-45b1-ae6f-02722378ab8f","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"fd21bed5-ab9f-48bf-a5d6-87b68e95f385","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"8789d147-1e52-45b1-ae6f-02722378ab8f","type":"LegendItem"},{"id":"0001eecf-550a-42f7-9a21-8fbd4f737711","type":"LegendItem"},{"id":"b65b2968-59a2-4089-9917-07d572dd49e5","type":"LegendItem"},{"id":"10a2a42d-67bc-4ac1-afe2-a9feb7b0c773","type":"LegendItem"},{"id":"1b9bfc0f-b0c0-4516-9cf9-8c93242619b8","type":"LegendItem"}],"plot":{"id":"d59ee073-d6eb-4058-9e01-2e7615e5b626","subtype":"Figure","type":"Plot"}},"id":"58930f86-1792-4d80-91e1-d33fc5aa95c0","type":"Legend"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b29613fc-e3fc-4fcd-8f19-b4159c0f83e1","type":"Line"},{"attributes":{"label":{"value":"fast group"},"renderers":[{"id":"577dc1d5-d39d-4520-8eb5-01ce134c8380","type":"GlyphRenderer"}]},"id":"0001eecf-550a-42f7-9a21-8fbd4f737711","type":"LegendItem"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"268aaceb-281c-41fb-9c9a-61e5edab9cd0","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d571249-3de0-4372-89c1-9b9711c19d71","type":"Line"},{"attributes":{"data_source":{"id":"fd21bed5-ab9f-48bf-a5d6-87b68e95f385","type":"ColumnDataSource"},"glyph":{"id":"b29613fc-e3fc-4fcd-8f19-b4159c0f83e1","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2d571249-3de0-4372-89c1-9b9711c19d71","type":"Line"},"selection_glyph":null},"id":"2c8fed5d-59ed-4ec3-aa18-ac87e7bf435e","type":"GlyphRenderer"},{"attributes":{},"id":"e9347fd0-729e-4df4-bfa0-876de28d8320","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"529bc744-09d1-4d19-9528-45d01172e3db","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c9fc7f9f-d561-42c8-a94f-c18d10d6ae66","type":"BoxAnnotation"},{"attributes":{"line_color":{"value ...

# %% [markdown]
# While at first this seems a bit strange (the oscillatory nature of the probability of being in the slow group), on closer inspection we see this does make sense.  A time close to mean values of the distributions would get grouped with that distribution.  The reason the probability of the slow group goes back up for the quickest times, $t < $ 4.18 min, is that group has such a wide standard deviation that the probability decays much slower than for the narrow distribution of the fast group.
#
# While the larger standard deviation makes it more likely the fastest runner did not train, we could impose a constraint to have "p fast" smoothly transition to 1 at the quickest times.  This would coorespond to the slow group having a more assymmetric distribution, more likely exhibiting a longer tail toward the slower times.

# %% [markdown]
# Lets compare my original probability and this corrected one.

# %%
p_per = bokeh.plotting.figure(width=400, height=300,
                              y_axis_label='% of People')
p_per.line(x, y, legend='combined', color=palette[0], line_width=2)
p_per.line(x, y1, legend='fast group', color=palette[1])
p_per.line(x, y2, legend='slow group', color=palette[2])

p_prob = bokeh.plotting.figure(width=400, height=300,
                               y_axis_label='Probability',
                               x_range=p_per.x_range)
p_prob.line(x, p1_v1, legend='p_v1 fast', color=palette[3])
p_prob.line(x, p2_v1, legend='p_v1 slow', color=palette[4])
p_prob.line(x, p1_v2, legend='p_v2 fast', color=palette[3], line_dash='dashed')
p_prob.line(x, p2_v2, legend='p_v2 slow', color=palette[4], line_dash='dashed')

p_diff = bokeh.plotting.figure(width=400, height=100,
                               x_axis_label='Time (m)',
                               y_axis_label='Residuals',
                               x_range=p_per.x_range)
p_diff.line(x, p1_v2-p1_v1, color=palette[3])
p_diff.line(x, p2_v2-p2_v1, color=palette[4])

p = bokeh.layouts.gridplot([[p_per], [p_prob], [p_diff]])
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7a266c45-4d6d-4c2c-a315-2ae8b63799ec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7a266c45-4d6d-4c2c-a315-2ae8b63799ec");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a266c45-4d6d-4c2c-a315-2ae8b63799ec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a266c45-4d6d-4c2c-a315-2ae8b63799ec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"da14123c-24d7-4206-ad0b-057c3f082d25":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"44b0ec49-6837-4f8f-aa91-14df358428d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"469ed3d9-7c4b-45c9-a3c0-e5410f940254","type":"BasicTicker"}},"id":"554792df-fa11-4c4c-87a1-63e73d5d2900","type":"Grid"},{"attributes":{"data_source":{"id":"5ac6bb6a-29a9-4df5-bd37-e4fd10e52ccd","type":"ColumnDataSource"},"glyph":{"id":"54efdcff-6ad7-4f89-a071-5c3dbc9bd145","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a4ddc515-52b7-408c-99b4-5886aa995b4b","type":"Line"},"selection_glyph":null},"id":"02a9e0ca-9a90-44a9-9f5d-e05d3f068981","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"47c13518-c0ba-4f3f-acde-08417ffe0bd5","type":"BoxAnnotation"},"plot":{"id":"44b0ec49-6837-4f8f-aa91-14df358428d0","subtype":"Figure","type":"Plot"}},"id":"cec3aab8-4c67-4090-a4c6-7283a24c2771","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"30e93280-00b7-4c2b-9bc4-fcbb369471b5","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"07251a19-219e-430d-8b93-b77c10e03f98","type":"LinearAxis"}],"left":[{"id":"5e6e3f6b-94b7-4fe4-8ac4-b3e49f21fa1f","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"07251a19-219e-430d-8b93-b77c10e03f98","type":"LinearAxis"},{"id":"794c6b87-3998-45d2-9eff-204e2ba670a7","type":"Grid"},{"id":"5e6e3f6b-94b7-4fe4-8ac4-b3e49f21fa1f","type":"LinearAxis"},{"id":"270f88cd-a5cc-44d3-90fd-2168a33cc058","type":"Grid"},{"id":"8ad8872f-2800-4b48-a304-937ac54c1804","type":"BoxAnnotation"},{"id":"dd18be7f-50a1-48ab-8285-1403c707fd5a","type":"Legend"},{"id":"3e27a541-8b7e-4ba7-8d19-f3ac972c55fd","type":"GlyphRenderer"},{"id":"6a3555c7-e75b-4d37-a101-ed7b93555562","type":"GlyphRenderer"},{"id":"f63c1157-c79e-42cd-8c6d-a9de565afd3d","type":"GlyphRenderer"},{"id":"46e231a4-a7ff-423a-91a5-ec93d8b8fba3","type":"GlyphRenderer"}],"title":{"id":"ff8bc01a-e2bd-4ad0-bb4b-21096b01dd22","type":"Title"},"tool_events":{"id":"03625ce3-6127-4994-8242-6686ab203d96","type":"ToolEvents"},"toolbar":{"id":"134d6f63-6698-4409-9d05-f18a9ed70802","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"d618778e-9d55-4627-a59b-28a080ae3114","type":"DataRange1d"},"y_range":{"id":"99631329-f759-473c-91e2-60cd2e6bab6b","type":"DataRange1d"}},"id":"96b97bf9-d084-4577-8036-273d40b019e8","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f955d36-ba91-4c69-8d32-48fbd2dbd3e4","type":"Line"},{"attributes":{"plot":{"id":"44b0ec49-6837-4f8f-aa91-14df358428d0","subtype":"Figure","type":"Plot"}},"id":"11dd90d8-aa79-4f55-864c-512aa917348b","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"4cd1c50f-66b1-44aa-8416-f288fdcfc2fe","type":"ColumnDataSource"},{"attributes":{},"id":"d8cb42cd-f1b0-4ed2-93f6-fd2f44e68c93","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"combined"},"renderers":[{"id":"02dff902-218a-44af-94e9-f673364f39a8","type":"GlyphRenderer"}]},"id":"78aa3642-c40a-4943-a165-7443bcdea9c2","type":"LegendItem"},{"attributes":{"items":[{"id":"78aa3642-c40a-4943-a165-7443bcdea9c2","type":"LegendItem"},{"id":"dd0189f4-7d11-4b6f-807d-30159d9131d2","type":"LegendItem"},{"id":"f2524e2c-dc52-442a-a572-658c1d0a547e","type":"LegendItem"}],"plot":{"id":"44b0ec49-6837-4f8f-aa91-14df358428d0","subtype":"Figure","type":"Plot"}},"id":"11b6e9ff-620a-44db-82f4-145a92a22a20","type":"Legend"},{"attributes":{},"id":"5d3e6a39-1318-4bc3-b2a3-09eecc56ddf5","type":"BasicTicker"},{"attributes":{"plot":{"id":"44b0ec49-6837-4f8f-aa91-14df358428d0","subtype":"Figure","type":"Plot"}},"id":"e1589334-0547-48b ...

# %% [markdown]
# This shows a general agreement though there are some important differences.
